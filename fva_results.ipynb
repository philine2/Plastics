# %%
# Prerequisites 

from pathlib import Path
import pandas as pd
from ordered_set import OrderedSet
import glob
import seaborn as sns
import matplotlib.pyplot as plt
import yaml
import json
from yaml.loader import SafeLoader
import cobra
from cobra.io import load_model
from cobra import Model, Reaction, Metabolite
from pathlib import Path
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model, load_model, load_yaml_model, save_yaml_model
import logging
from cobra.sampling import sample
from cobra.medium import minimal_medium
import ast
import sys
import numpy as np

# %% [markdown]
# # load model

# %%
eg_path = Path("/Users/philine/Downloads/yeast-GEM-8.6.2/model")
yml_path = eg_path / "yeast-GEM.yml"
model = load_yaml_model(str(yml_path.resolve()))
model
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# <Model None at 0x7f9e4fcd71d0>

# %% [markdown]
# # load csvs

# %%
# read csv of growing pathways
growth_csv = pd.read_csv('final.csv')
growth_csv['INTERMEDIATE NAMES'] = [ast.literal_eval(i) for i in growth_csv['INTERMEDIATE NAMES']]
growth_csv['INTERMEDIATES KEGG'] = [ast.literal_eval(i) for i in growth_csv['INTERMEDIATES KEGG']]
growth_csv
# Out:
#     LENGTH                                 INTERMEDIATES KEGG  \
# 0        6  [C06793, C20609, C00288, C00222, C10020, C0460...
# 1        6  [C06793, C06614, C06613, C01471, C05608, C0656...
# 2        6  [C06793, C06614, C00288, C00222, C10020, C0460...
# 3        6  [C06793, C20609, C00288, C00222, C10020, C0460...
# 4        6  [C06793, C06614, C00288, C00222, C10020, C0460...
# 5        6  [C06793, C06614, C06613, C01471, C00903, C1640...
# 6        6  [C06793, C06753, C00007, C14448, C00546, C1972...
# 7        6  [C06793, C20303, C00007, C00067, C00546, C1972...
# 8        6  [C06793, C20303, C00007, C00067, C00546, C1228...
# 9        6  [C06793, C20303, C00007, C00048, C00546, C1972...
# 10       6  [C06793, C20303, C00007, C00048, C00546, C1228...
# 11       6  [C06793, C20303, C00007, A00148, C00546, C1972...
# 12       6  [C06793, C20303, C00007, A00148, C00546, C1228...
# 13       6  [C06793, C06753, C00007, C14448, C00546, C1228...
# 14       6  [C06793, C20303, C00007, C14448, C00546, C1972...
# 15       6  [C06793, C06753, C00007, C00067, C00546, C1972...
# 16       6  [C06793, C06753, C00007, C00067, C00546, C1228...
# 17       6  [C06793, C06753, C00007, C00048, C00546, C1972...
# 18       6  [C06793, C06753, C00007, C00048, C00546, C1228...
# 19       6  [C06793, C06753, C00007, A00148, C00546, C1972...
# 20       6  [C06793, C06753, C00007, A00148, C00546, C1228...
# 21       6  [C06793, C20303, C00007, C14448, C00546, C1228...
# 22       6  [C06793, C20609, C00288, A00654, C00546, C1228...
# 23       6  [C06793, C20609, A00264, C00048, C00546, C1972...
# 24       6  [C06793, C20609, A00264, C00048, C00546, C1228...
# 25       6  [C06793, C20609, C00288, A00654, C00546, C1972...
# 26       6  [C06793, C20609, C00288, C00048, C00546, C1972...
# 27       6  [C06793, C20609, C00288, C00048, C00546, C1228...
# 28       6  [C06793, C06614, C00288, A00654, C00546, C1228...
# 29       6  [C06793, C06614, C00288, C00048, C00546, C1228...
# 30       6  [C06793, C06614, C00288, A00654, C00546, C1972...
# 31       6  [C06793, C06614, C00288, C00048, C00546, C1972...
# 32       6  [C06793, C06614, A00264, C00048, C00546, C1972...
# 33       6  [C06793, C06753, A00455, C00048, C00546, C1972...
# 34       6  [C06793, C06753, A00455, C00048, C00546, C1228...
# 35       6  [C06793, C06614, A00264, C00048, C00546, C1228...
# 36       6  [C06793, C06614, C06613, C01471, C10945, C1552...
# 37       6  [C06793, C20609, C00288, C00222, C10103, C0395...
# 38       6  [C06793, C06614, C00288, C00222, C10103, C0395...
# 39       5   [C11505, C01771, C00048, C00546, C12287, C02094]
# 40       5   [C11505, C01771, C00048, C00546, C19728, C02094]
# 41       4           [C11505, C01771, C00048, C00149, A00704]
#
#                                    INTERMEDIATE NAMES      solution
# 0   [Vinyl chloride, 2-Chloroacrylate, H2CO3, 3-Ox...  9.379374e+00
# 1   [Vinyl chloride, trans-3-Chloroacrylic acid, t...  1.186644e-17
# 2   [Vinyl chloride, trans-3-Chloroacrylic acid, H...  9.379374e+00
# 3   [Vinyl chloride, 2-Chloroacrylate, H2CO3, 3-Ox...  9.379374e+00
# 4   [Vinyl chloride, trans-3-Chloroacrylic acid, H...  9.379374e+00
# 5   [Vinyl chloride, trans-3-Chloroacrylic acid, t...  2.138682e-17
# 6   [Vinyl chloride, 2-Chloroethanol, Oxygen, Glyo...  6.126559e+00
# 7   [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.126559e+00
# 8   [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.126559e+00
# 9   [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.322964e+00
# 10  [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.322964e+00
# 11  [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.126559e+00
# 12  [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.126559e+00
# 13  [Vinyl chloride, 2-Chloroethanol, Oxygen, Glyo...  6.126559e+00
# 14  [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.126559e+00
# 15  [Vinyl chloride, 2-Chloroethanol, Oxygen, Form...  6.126559e+00
# 16  [Vinyl chloride, 2-Chloroethanol, Oxygen, Form...  6.126559e+00
# 17  [Vinyl chloride, 2-Chloroethanol, Oxygen, Glyo...  6.322964e+00
# 18  [Vinyl chloride, 2-Chloroethanol, Oxygen, Glyo...  6.322964e+00
# 19  [Vinyl chloride, 2-Chloroethanol, Oxygen, Acet...  6.126559e+00
# 20  [Vinyl chloride, 2-Chloroethanol, Oxygen, Acet...  6.126559e+00
# 21  [Vinyl chloride, Chloroethylene oxide, Oxygen,...  6.126559e+00
# 22  [Vinyl chloride, 2-Chloroacrylate, H2CO3, Pyru...  6.126559e+00
# 23  [Vinyl chloride, 2-Chloroacrylate, CO2, Glyoxa...  1.795530e+00
# 24  [Vinyl chloride, 2-Chloroacrylate, CO2, Glyoxa...  1.795530e+00
# 25  [Vinyl chloride, 2-Chloroacrylate, H2CO3, Pyru...  6.126559e+00
# 26  [Vinyl chloride, 2-Chloroacrylate, H2CO3, Glyo...  6.322964e+00
# 27  [Vinyl chloride, 2-Chloroacrylate, H2CO3, Glyo...  6.322964e+00
# 28  [Vinyl chloride, trans-3-Chloroacrylic acid, H...  6.126559e+00
# 29  [Vinyl chloride, trans-3-Chloroacrylic acid, H...  6.322964e+00
# 30  [Vinyl chloride, trans-3-Chloroacrylic acid, H...  6.126559e+00
# 31  [Vinyl chloride, trans-3-Chloroacrylic acid, H...  6.322964e+00
# 32  [Vinyl chloride, trans-3-Chloroacrylic acid, C...  1.795530e+00
# 33  [Vinyl chloride, 2-Chloroethanol, H2O, Glyoxal...  1.795530e+00
# 34  [Vinyl chloride, 2-Chloroethanol, H2O, Glyoxal...  1.795530e+00
# 35  [Vinyl chloride, trans-3-Chloroacrylic acid, C...  1.795530e+00
# 36  [Vinyl chloride, trans-3-Chloroacrylic acid, t...  1.450803e-17
# 37  [Vinyl chloride, 2-Chloroacrylate, H2CO3, 3-Ox...  9.379374e+00
# 38  [Vinyl chloride, trans-3-Chloroacrylic acid, H...  9.379374e+00
# 39  [Propene, 2-Butenoate, Glyoxalate, 2-Oxopropan...  1.795530e+00
# 40  [Propene, 2-Butenoate, Glyoxalate, 2-Oxopropan...  1.795530e+00
# 41  [Propene, 2-Butenoate, Glyoxalate, L-Malate, S...  2.586895e+00

# %%
# read csv of pathway generating highest yield 
max_pathway = pd.read_csv('max_pathway.csv')
max_pathway['INTERMEDIATE NAMES'] = [ast.literal_eval(i) for i in max_pathway['INTERMEDIATE NAMES']]
max_pathway['INTERMEDIATES KEGG'] = [ast.literal_eval(i) for i in max_pathway['INTERMEDIATES KEGG']]
max_pathway
# Out:
#    LENGTH                                 INTERMEDIATES KEGG  \
# 0       6  [C06793, C20609, C00288, C00222, C10020, C0460...
#
#                                   INTERMEDIATE NAMES  solution
# 0  [Vinyl chloride, 2-Chloroacrylate, H2CO3, 3-Ox...  9.379374

# %% [markdown]
# ## select pathway to utilise

# %%
df = max_pathway

# %% [markdown]
# # prep model

# %%
# preapre model and apply to yeast model
def prep_model(model):
    
    model.solver = 'glpk'
    model.objective = 'r_4041'
    
    medium = model.medium
    medium['r_1714'] = 0.0
    model.medium = medium
    
    return model

model = prep_model(model)

# %%
#get csv containing s id and kegg id
sid_kegg = pd.read_csv('map_sid_kegg.csv')


# create dictionary of sid_kegg data frame
sk_dict = dict(zip(sid_kegg['S ID'], sid_kegg['KEGG ID']))
sk_dict
# Out:
# {'s_0002': 'C00965',
#  's_0007': 'C11514',
#  's_0009': 'C04411',
#  's_0010': 'C04236',
#  's_0013': nan,
#  's_0015': 'C03406',
#  's_0017': 'C03492',
#  's_0018': 'C01143',
#  's_0019': 'C01107',
#  's_0020': 'C00810',
#  's_0021': 'C00318',
#  's_0025': 'C00256',
#  's_0028': 'C00418',
#  's_0030': 'C00522',
#  's_0031': 'C00864',
#  's_0033': 'C03451',
#  's_0035': 'C03044',
#  's_0037': 'C01054',
#  's_0056': 'C00671',
#  's_0061': 'C00337',
#  's_0062': 'C00424',
#  's_0063': 'C00186',
#  's_0066': 'C00149',
#  's_0075': 'C00236',
#  's_0076': 'C01302',
#  's_0077': 'C04896',
#  's_0078': 'C02741',
#  's_0079': 'C01225',
#  's_0086': 'C03506',
#  's_0087': 'C02918',
#  's_0089': 'C01194',
#  's_0116': 'C04281',
#  's_0118': 'C04322',
#  's_0120': 'C00234',
#  's_0122': 'C05108',
#  's_0126': 'C01177',
#  's_0131': 'C02353',
#  's_0132': 'C00559',
#  's_0134': 'C00330',
#  's_0136': 'C05512',
#  's_0138': 'C00526',
#  's_0140': 'C01159',
#  's_0141': 'C01304',
#  's_0142': 'C18910',
#  's_0143': 'C04441',
#  's_0144': 'C04692',
#  's_0147': 'C04409',
#  's_0149': 'C00966',
#  's_0152': 'C01801',
#  's_0153': 'C00673',
#  's_0158': 'C15556',
#  's_0162': 'C02504',
#  's_0165': 'C02631',
#  's_0166': 'C02223',
#  's_0169': nan,
#  's_0172': nan,
#  's_0176': 'C00322',
#  's_0178': 'C00109',
#  's_0180': 'C00026',
#  's_0185': 'C05853',
#  's_0188': 'C00631',
#  's_0189': 'C00353',
#  's_0190': 'C00448',
#  's_0192': 'C00575',
#  's_0193': 'C00941',
#  's_0194': 'C00968',
#  's_0195': 'C00942',
#  's_0196': 'C00943',
#  's_0197': 'C00882',
#  's_0201': 'C00053',
#  's_0204': 'C01179',
#  's_0207': 'C01267',
#  's_0208': 'C02229',
#  's_0209': 'C15816',
#  's_0210': 'C00944',
#  's_0211': 'C02637',
#  's_0212': 'C05200',
#  's_0215': 'C13425',
#  's_0217': nan,
#  's_0218': 'C00356',
#  's_0222': 'C03227',
#  's_0224': 'C00632',
#  's_0232': 'C00141',
#  's_0234': 'C07329',
#  's_0258': 'C03232',
#  's_0259': 'C01005',
#  's_0260': 'C00197',
#  's_0261': 'C03175',
#  's_0262': 'C11455',
#  's_0263': nan,
#  's_0264': 'C06055',
#  's_0267': 'C04752',
#  's_0268': 'C04556',
#  's_0269': 'C11355',
#  's_0270': 'C01279',
#  's_0271': 'C00568',
#  's_0274': 'C00555',
#  's_0279': 'C11526',
#  's_0280': 'C03078',
#  's_0281': 'C01035',
#  's_0282': 'C01127',
#  's_0285': 'C06056',
#  's_0286': 'C00156',
#  's_0291': 'C00233',
#  's_0293': 'C04327',
#  's_0294': 'C01180',
#  's_0295': 'C03082',
#  's_0296': 'C05103',
#  's_0297': 'C15808',
#  's_0298': 'C00224',
#  's_0299': 'C04823',
#  's_0300': 'C03373',
#  's_0301': 'C04376',
#  's_0302': 'C04640',
#  's_0303': 'C00170',
#  's_0304': 'C00445',
#  's_0306': 'C00143',
#  's_0308': 'C09332',
#  's_0309': nan,
#  's_0310': 'C04294',
#  's_0311': 'C15650',
#  's_0312': 'C04916',
#  's_0313': 'C04454',
#  's_0314': 'C04732',
#  's_0315': 'C00430',
#  's_0318': 'C11526',
#  's_0319': 'C03479',
#  's_0322': 'C00440',
#  's_0323': 'C04489',
#  's_0324': 'C01269',
#  's_0325': 'C03838',
#  's_0326': 'C02739',
#  's_0327': 'C03090',
#  's_0328': 'C04332',
#  's_0333': 'C11526',
#  's_0335': 'C01236',
#  's_0340': 'C00345',
#  's_0341': 'C01037',
#  's_0343': 'C04874',
#  's_0345': 'C05925',
#  's_0346': 'C04895',
#  's_0347': 'C00921',
#  's_0349': 'C04691',
#  's_0352': 'C01092',
#  's_0357': 'C00385',
#  's_0359': 'C00084',
#  's_0362': 'C00033',
#  's_0367': 'C00332',
#  's_0373': 'C00024',
#  's_0383': 'C00147',
#  's_0386': 'C00212',
#  's_0389': 'C00946',
#  's_0390': 'C00054',
#  's_0393': 'C03794',
#  's_0394': 'C00008',
#  's_0403': 'C04677',
#  's_0404': 'C00886',
#  's_0405': 'C00499',
#  's_0407': 'C01551',
#  's_0409': 'C00689',
#  's_0410': 'C00446',
#  's_0411': 'C06156',
#  's_0412': 'C00352',
#  's_0415': 'C00620',
#  's_0417': 'C06735',
#  's_0418': 'C01888',
#  's_0419': 'C01342',
#  's_0423': 'C00020',
#  's_0427': 'C00108',
#  's_0428': 'C02163',
#  's_0430': 'C03402',
#  's_0432': 'C02984',
#  's_0434': 'C00002',
#  's_0441': 'C00099',
#  's_0442': 'C00665',
#  's_0443': 'C05860',
#  's_0445': 'C00288',
#  's_0450': nan,
#  's_0451': 'C00120',
#  's_0453': 'C05921',
#  's_0455': 'C00169',
#  's_0456': 'C00011',
#  's_0467': 'C00112',
#  's_0469': 'C00307',
#  's_0474': 'C00570',
#  's_0509': 'C00461',
#  's_0512': 'C00114',
#  's_0514': 'C00588',
#  's_0515': 'C00251',
#  's_0516': 'C00417',
#  's_0522': 'C00158',
#  's_0526': 'C00055',
#  's_0529': 'C00010',
#  's_0538': 'C03263',
#  's_0539': 'C00063',
#  's_0542': 'C03125',
#  's_0543': 'C00475',
#  's_0545': 'C00380',
#  's_0547': 'C00652',
#  's_0548': 'C00216',
#  's_0550': 'C04666',
#  's_0551': 'C00279',
#  's_0553': 'C00095',
#  's_0555': 'C00354',
#  's_0556': 'C01094',
#  's_0557': 'C00085',
#  's_0558': 'C00124',
#  's_0561': 'C00794',
#  's_0563': 'C00031',
#  's_0567': 'C00103',
#  's_0568': 'C00092',
#  's_0570': 'C00577',
#  's_0571': 'C00159',
#  's_0573': 'C00636',
#  's_0574': 'C00275',
#  's_0575': 'C00121',
#  's_0577': 'C00199',
#  's_0578': 'C00181',
#  's_0580': 'C00310',
#  's_0581': 'C00231',
#  's_0582': 'C00206',
#  's_0584': 'C00360',
#  's_0586': 'C00131',
#  's_0587': 'C00705',
#  's_0589': 'C00239',
#  's_0590': 'C00458',
#  's_0591': 'C00857',
#  's_0595': 'C01571',
#  's_0607': 'C06316',
#  's_0608': nan,
#  's_0610': 'C00881',
#  's_0612': 'C01909',
#  's_0613': 'C00361',
#  's_0615': 'C00362',
#  's_0617': 'C00286',
#  's_0618': 'C01344',
#  's_0625': 'C00415',
#  's_0629': 'C00111',
#  's_0633': 'C00013',
#  's_0639': 'C01345',
#  's_0642': 'C00381',
#  's_0645': 'C00110',
#  's_0647': 'C00363',
#  's_0649': 'C00364',
#  's_0650': 'C00459',
#  's_0652': 'C01346',
#  's_0654': 'C00365',
#  's_0656': 'C00460',
#  's_0657': 'C15777',
#  's_0662': 'C05440',
#  's_0664': 'C15780',
#  's_0666': 'C01694',
#  's_0670': nan,
#  's_0672': nan,
#  's_0677': 'C05947',
#  's_0680': 'C00469',
#  's_0683': 'C00189',
#  's_0685': 'C00849',
#  's_0687': 'C00016',
#  's_0689': 'C01352',
#  's_0694': 'C00162',
#  's_0700': 'C04525',
#  's_0714': 'C00061',
#  's_0717': 'C01847',
#  's_0719': 'C00504',
#  's_0721': 'C00067',
#  's_0722': 'C00058',
#  's_0725': 'C00122',
#  's_0734': 'C00334',
#  's_0739': 'C00035',
#  's_0743': 'C00096',
#  's_0745': 'C00341',
#  's_0747': 'C02282',
#  's_0748': 'C02987',
#  's_0750': 'C00051',
#  's_0754': 'C00127',
#  's_0757': 'C02412',
#  's_0764': 'C00661',
#  's_0765': 'C00116',
#  's_0767': 'C00093',
#  's_0771': 'C00184',
#  's_0773': 'C00182',
#  's_0775': 'C00266',
#  's_0779': 'C00048',
#  's_0782': 'C00144',
#  's_0785': 'C00044',
#  's_0787': 'C00242',
#  's_0790': 'C00387',
#  's_0794': 'C00080',
#  's_0803': 'C00001',
#  's_0816': nan,
#  's_0832': 'C02988',
#  's_0837': 'C00027',
#  's_0841': 'C00283',
#  's_0843': 'C00262',
#  's_0846': 'C00104',
#  's_0847': 'C03127',
#  's_0849': 'C00130',
#  's_0850': 'C00637',
#  's_0853': 'C00954',
#  's_0855': 'C00331',
#  's_0856': 'C00294',
#  's_0924': 'C14818',
#  's_0927': 'C12296',
#  's_0929': 'C07328',
#  's_0932': 'C14710',
#  's_0935': nan,
#  's_0937': nan,
#  's_0940': 'C00311',
#  's_0943': 'C00129',
#  's_0950': 'C00081',
#  's_0951': 'C00166',
#  's_0952': 'C03508',
#  's_0953': 'C00956',
#  's_0955': 'C00041',
#  's_0958': 'C05519',
#  's_0959': 'C04076',
#  's_0960': 'C11822',
#  's_0961': 'C00532',
#  's_0963': 'C00259',
#  's_0965': 'C00062',
#  's_0969': 'C00152',
#  's_0973': 'C00049',
#  's_0978': 'C00441',
#  's_0979': 'C00327',
#  's_0980': 'C02291',
#  's_0981': 'C00097',
#  's_0983': 'C01419',
#  's_0984': 'C00491',
#  's_0986': 'C03287',
#  's_0987': 'C03738',
#  's_0988': 'C00669',
#  's_0989': 'C01722',
#  's_0991': 'C00025',
#  's_0997': 'C01165',
#  's_0999': 'C00064',
#  's_1003': 'C00037',
#  's_1006': 'C00135',
#  's_1010': 'C00860',
#  's_1011': 'C01100',
#  's_1012': 'C00155',
#  's_1014': 'C00263',
#  's_1016': 'C00407',
#  's_1020': 'C00328',
#  's_1021': 'C00123',
#  's_1025': 'C00047',
#  's_1029': 'C00073',
#  's_1032': 'C00079',
#  's_1035': 'C00148',
#  's_1038': 'C00449',
#  's_1039': 'C00065',
#  's_1043': 'C00247',
#  's_1045': 'C00188',
#  's_1048': 'C00078',
#  's_1051': 'C00082',
#  's_1056': 'C00183',
#  's_1059': 'C01724',
#  's_1065': 'C02679',
#  's_1073': 'C01832',
#  's_1077': 'C02047',
#  's_1079': 'C00909',
#  's_1081': 'C02165',
#  's_1096': 'C01356',
#  's_1099': 'C01931',
#  's_1101': 'C00083',
#  's_1105': 'C00208',
#  's_1107': 'C00464',
#  's_1148': 'C02430',
#  's_1150': 'C00409',
#  's_1151': 'C00546',
#  's_1153': 'C00137',
#  's_1156': 'C01284',
#  's_1158': 'C01204',
#  's_1161': 'C06424',
#  's_1176': 'C02593',
#  's_1180': 'C00612',
#  's_1181': 'C02567',
#  's_1183': 'C01152',
#  's_1184': 'C04537',
#  's_1185': nan,
#  's_1187': 'C04302',
#  's_1188': 'C04352',
#  's_1189': 'C04501',
#  's_1190': 'C00357',
#  's_1193': 'C02714',
#  's_1194': 'C00438',
#  's_1195': 'C02700',
#  's_1196': nan,
#  's_1198': 'C00003',
#  's_1203': 'C00004',
#  's_1207': 'C00006',
#  's_1212': 'C00005',
#  's_1216': 'C00153',
#  's_1218': 'C03150',
#  's_1219': 'C00253',
#  's_1222': 'C01185',
#  's_1224': 'C00455',
#  's_1230': 'C03885',
#  's_1231': 'C04145',
#  's_1233': 'C01077',
#  's_1234': 'C00979',
#  's_1235': 'C02571',
#  's_1238': 'C01102',
#  's_1239': 'C00346',
#  's_1241': 'C01118',
#  's_1248': 'C06423',
#  's_1260': 'C00712',
#  's_1262': 'C00510',
#  's_1266': 'C01602',
#  's_1269': 'C00295',
#  's_1270': 'C01103',
#  's_1271': 'C00036',
#  's_1275': 'C00007',
#  's_1282': 'C01260',
#  's_1283': 'C01261',
#  's_1284': nan,
#  's_1286': 'C00249',
#  's_1293': 'C08362',
#  's_1302': 'C00154',
#  's_1307': 'C01134',
#  's_1311': 'C04217',
#  's_1314': 'C03511',
#  's_1316': 'C12303',
#  's_1318': 'C00601',
#  's_1321': 'C07086',
#  's_1322': 'C00009',
#  's_1337': 'C02737',
#  's_1346': 'C00157',
#  's_1351': 'C00350',
#  's_1360': 'C00074',
#  's_1364': 'C04751',
#  's_1365': 'C04734',
#  's_1368': 'C01063',
#  's_1371': 'C00087',
#  's_1372': 'C00931',
#  's_1373': 'C00238',
#  's_1375': 'C02463',
#  's_1376': 'C00235',
#  's_1377': 'C00254',
#  's_1378': 'C01024',
#  's_1379': 'C02702',
#  's_1384': 'C01079',
#  's_1386': 'C00119',
#  's_1388': 'C01168',
#  's_1389': 'C00134',
#  's_1392': 'C00250',
#  's_1393': 'C00018',
#  's_1394': 'C00534',
#  's_1395': 'C00647',
#  's_1396': 'C00314',
#  's_1398': 'C00627',
#  's_1399': 'C00022',
#  's_1403': 'C03722',
#  's_1405': 'C00255',
#  's_1408': 'C03736',
#  's_1412': 'C04425',
#  's_1413': 'C00021',
#  's_1416': 'C00019',
#  's_1420': 'C01137',
#  's_1421': 'C01031',
#  's_1422': 'C04188',
#  's_1423': 'C04582',
#  's_1424': 'C03172',
#  's_1426': 'C00447',
#  's_1427': 'C05382',
#  's_1428': 'C02553',
#  's_1429': 'C00493',
#  's_1430': 'C00748',
#  's_1431': 'C05778',
#  's_1433': 'C00670',
#  's_1437': 'C01330',
#  's_1439': 'C00315',
#  's_1442': 'C00750',
#  's_1447': 'C00751',
#  's_1449': 'C01530',
#  's_1454': 'C00412',
#  's_1458': 'C00042',
#  's_1461': 'C00232',
#  's_1467': 'C00059',
#  's_1469': 'C11481',
#  's_1471': 'C00245',
#  's_1473': 'C05122',
#  's_1475': 'C00068',
#  's_1479': 'C16529',
#  's_1486': 'C04144',
#  's_1487': 'C00101',
#  's_1489': 'C00378',
#  's_1491': 'C02992',
#  's_1493': 'C00214',
#  's_1497': 'C01081',
#  's_1503': 'C02341',
#  's_1520': 'C01083',
#  's_1524': 'C00422',
#  's_1526': 'C00986',
#  's_1527': 'C03512',
#  's_1529': 'C00955',
#  's_1532': 'C03028',
#  's_1533': 'C02839',
#  's_1538': 'C00015',
#  's_1541': 'C00052',
#  's_1543': 'C00029',
#  's_1544': 'C00043',
#  's_1545': 'C00105',
#  's_1550': 'C00106',
#  's_1552': 'C00086',
#  's_1554': 'C01010',
#  's_1555': 'C05241',
#  's_1556': 'C00299',
#  's_1558': 'C01051',
#  's_1559': 'C00075',
#  's_1561': 'C02554',
#  's_1563': 'C01762',
#  's_1565': 'C00655',
#  's_1566': 'C00379',
#  's_1569': 'C05437',
#  's_1576': nan,
#  's_1577': nan,
#  's_1578': nan,
#  's_1579': nan,
#  's_1582': 'C01635',
#  's_1583': 'C01636',
#  's_1585': 'C01637',
#  's_1587': 'C01638',
#  's_1589': 'C01639',
#  's_1590': 'C01640',
#  's_1591': 'C01641',
#  's_1593': 'C01642',
#  's_1594': 'C01643',
#  's_1596': 'C01644',
#  's_1598': 'C01645',
#  's_1600': 'C01646',
#  's_1602': 'C01647',
#  's_1604': 'C01648',
#  's_1606': 'C01649',
#  's_1607': 'C01650',
#  's_1608': 'C01651',
#  's_1610': 'C01652',
#  's_1612': 'C00787',
#  's_1614': 'C01653',
#  's_1616': 'C00342',
#  's_1620': 'C00343',
#  's_2763': 'C01717',
#  's_2764': 'C06325',
#  's_2828': 'C00246',
#  's_2829': 'C01585',
#  's_2877': 'C21072',
#  's_2878': 'C02041',
#  's_2880': 'C16528',
#  's_3496': nan,
#  's_3497': nan,
#  's_3498': 'C01245',
#  's_3499': nan,
#  's_3500': nan,
#  's_3501': nan,
#  's_3502': nan,
#  's_3503': nan,
#  's_3504': nan,
#  's_3505': nan,
#  's_3506': nan,
#  's_3507': nan,
#  's_3508': nan,
#  's_3509': nan,
#  's_3510': nan,
#  's_3511': nan,
#  's_3512': nan,
#  's_3544': nan,
#  's_3545': nan,
#  's_3546': nan,
#  's_3547': nan,
#  's_3548': nan,
#  's_3549': nan,
#  's_3550': nan,
#  's_3551': nan,
#  's_3552': nan,
#  's_3553': 'C13888',
#  's_3554': nan,
#  's_3555': nan,
#  's_3556': nan,
#  's_3557': nan,
#  's_3558': nan,
#  's_3559': nan,
#  's_3576': nan,
#  's_3577': nan,
#  's_3578': nan,
#  's_3579': nan,
#  's_3580': nan,
#  's_3581': nan,
#  's_3582': nan,
#  's_3583': nan,
#  's_3600': nan,
#  's_3601': nan,
#  's_3602': nan,
#  's_3603': nan,
#  's_3604': nan,
#  's_3605': nan,
#  's_3606': nan,
#  's_3607': nan,
#  's_3632': 'C04036',
#  's_3633': nan,
#  's_3634': nan,
#  's_3635': nan,
#  's_3636': nan,
#  's_3637': nan,
#  's_3638': nan,
#  's_3639': nan,
#  's_3714': 'C15670',
#  's_3717': 'C00492',
#  's_3718': 'C05402',
#  's_3719': nan,
#  's_3720': nan,
#  's_3722': nan,
#  's_3723': nan,
#  's_3724': nan,
#  's_3725': nan,
#  's_3727': nan,
#  's_3729': nan,
#  's_3731': nan,
#  's_3733': nan,
#  's_3735': nan,
#  's_3737': nan,
#  's_3739': nan,
#  's_3740': nan,
#  's_3741': nan,
#  's_3742': nan,
#  's_3743': nan,
#  's_3744': nan,
#  's_3745': nan,
#  's_3746': nan,
#  's_3747': nan,
#  's_3750': 'C00741',
#  's_3760': nan,
#  's_3761': 'C00301',
#  's_3762': 'C00472',
#  's_3763': 'C02389',
#  's_3768': 'C00117',
#  's_3778': 'C00698',
#  's_3782': 'C01413',
#  's_3789': nan,
#  's_3790': nan,
#  's_3791': 'C03351',
#  's_3792': 'C03067',
#  's_3793': 'C07216',
#  's_3794': 'C07209',
#  's_3795': 'C06576',
#  's_3796': 'C06577',
#  's_3797': 'C06757',
#  's_3798': 'C06758',
#  's_3799': 'C00556',
#  's_3800': 'C00261',
#  's_3801': 'C19610',
#  's_3805': 'C00392',
#  's_3806': 'C06033',
#  's_3807': 'C15999',
#  's_3810': 'C01879',
#  's_3814': 'C06369',
#  's_3815': 'C00586',
#  's_3816': nan,
#  's_3817': nan,
#  's_3822': 'C00038',
#  's_3828': 'C20227',
#  's_3829': 'C20226',
#  's_3834': 'C01322',
#  's_3835': 'C00462',
#  's_3836': 'C02320',
#  's_3837': 'C02989',
#  's_3841': 'C11511',
#  's_3846': 'C05422',
#  's_3847': 'C00072',
#  's_3851': 'C01566',
#  's_3852': 'C00117',
#  's_3853': 'C05729',
#  's_3854': 'C05726',
#  's_3856': nan,
#  's_3857': nan,
#  's_3858': 'C06420',
#  's_3859': 'C03360',
#  's_3860': 'C00870',
#  's_3861': 'C01507',
#  's_3862': 'C00984',
#  's_3866': 'C00370',
#  's_3867': 'C02505',
#  's_3868': 'C02693',
#  's_3871': 'C00511',
#  's_3872': 'C01659',
#  's_3873': 'C09815',
#  's_3874': 'C00180',
#  's_3875': 'C00257',
#  's_3876': 'C04506',
#  's_3877': 'C04748',
#  's_3880': 'C00076',
#  's_3884': 'C00017',
#  's_3885': 'C16739',
#  's_3903': 'C20641',
#  's_3904': 'C00740',
#  's_3909': 'C17023',
#  's_3910': 'C20784',
#  's_3913': 'C00533',
#  's_3914': 'C00244',
#  's_3915': 'C16241',
#  's_3916': 'C16238',
#  's_3917': 'C16240',
#  's_3918': 'C16237',
#  's_3923': nan,
#  's_3927': 'C03802',
#  's_3928': 'C00171',
#  's_3929': 'C00677',
#  's_3930': 'C00676',
#  's_3931': 'C00704',
#  's_3934': 'C18091',
#  's_3935': 'C00088',
#  's_3940': 'C01573',
#  's_3941': 'C02872',
#  's_3948': 'C05345',
#  's_3949': 'C00221',
#  's_3950': 'C01172',
#  's_3951': 'C00267',
#  's_3952': 'C00668',
#  's_3953': 'C00329',
#  's_3954': 'C02336',
#  's_3958': 'C00258',
#  's_3959': 'C05985',
#  's_3960': 'C00804',
#  's_3961': 'C02670',
#  's_3962': 'C00818',
#  's_3963': 'C01149',
#  's_3964': 'C01181',
#  's_3965': 'C06002',
#  's_3966': 'C02170',
#  's_3967': 'C05130',
#  's_3968': 'C02835',
#  's_3969': 'C05445',
#  's_3970': 'C04554',
#  's_3971': 'C05634',
#  's_3972': 'C05635',
#  's_3973': 'C05936',
#  's_3974': 'C02946',
#  's_3975': 'C06613',
#  's_3976': 'C06614',
#  's_3977': 'C16348',
#  's_3978': 'C06615',
#  's_3979': 'C06754',
#  's_3980': 'C06755',
#  's_3981': 'C02576',
#  's_3982': 'C11924',
#  's_3983': 'C03461',
#  's_3984': 'C16502',
#  's_3988': nan,
#  's_3991': 'C00386',
#  's_3992': 'C01262',
#  's_3997': 'C00160',
#  's_3998': 'C00089',
#  's_3999': 'C00252',
#  's_4000': 'C00721',
#  's_4013': 'C00305',
#  's_4017': 'C00140',
#  's_4018': 'C00404',
#  's_4019': 'C00070',
#  's_4021': 'C00940',
#  's_4023': 'C05113',
#  's_4024': nan,
#  's_4032': 'C02188',
#  's_4033': nan,
#  's_4035': nan,
#  's_4038': 'C20958',
#  's_4041': nan,
#  's_4044': nan,
#  's_4046': nan,
#  's_4048': 'C03189',
#  's_4051': nan,
#  's_4054': nan,
#  's_4057': nan,
#  's_4060': nan,
#  's_4062': 'C02979',
#  's_4064': 'C12147',
#  's_4066': nan,
#  's_4068': 'C06193',
#  's_4071': 'C00988',
#  's_4072': nan,
#  's_4073': 'C01678',
#  's_4076': 'C00519',
#  's_4077': 'C02532',
#  's_4079': nan,
#  's_4081': 'C03031',
#  's_4083': 'C01368',
#  's_4086': nan,
#  's_4088': nan,
#  's_4089': 'C00791',
#  's_4092': 'C05945',
#  's_4094': 'C06194',
#  's_4096': 'C06501',
#  's_4098': 'C00536',
#  's_4100': 'C03104',
#  's_4102': 'C02355',
#  's_4104': 'C00606',
#  's_4106': 'C01367',
#  's_4108': 'C01742',
#  's_4110': 'C06809',
#  's_4112': 'C02084',
#  's_4113': 'C00320',
#  's_4115': 'C05123',
#  's_4117': 'C01062',
#  's_4120': nan,
#  's_4122': nan,
#  's_4123': 'C00132',
#  's_4126': 'C02354',
#  's_4128': 'C00795',
#  's_4129': 'C01097',
#  's_4132': 'C00164',
#  's_4134': 'C02712',
#  's_4136': 'C01990',
#  's_4138': 'C00506',
#  's_4144': nan,
#  's_4169': nan,
#  's_4171': nan,
#  's_4173': 'C00624',
#  's_4175': 'C00248',
#  's_4177': 'C00544',
#  's_4178': 'C01036',
#  's_4179': 'C01061',
#  's_4180': 'C00312',
#  's_4181': 'C01904',
#  's_4182': 'C02630',
#  's_4183': 'C00100',
#  's_4184': 'C00222',
#  's_4189': 'C06032',
#  's_4190': 'C02050',
#  's_4191': 'C01595',
#  's_4192': 'C01613',
#  's_4193': 'C00492',
#  's_4194': 'C00642',
#  's_4195': 'C00530',
#  's_4205': nan,
#  's_4206': nan,
#  's_4207': 'C01157',
#  's_4221': nan,
#  's_4222': 'C12292',
#  's_4223': nan,
#  's_4224': nan,
#  's_4225': nan,
#  's_4232': 'C00479',
#  's_4233': 'C05979',
#  's_4238': nan,
#  's_4239': nan,
#  's_4244': nan,
#  's_4245': 'C06044',
#  's_4250': 'C00163',
#  's_4254': nan,
#  's_4256': nan,
#  's_4258': nan,
#  's_4261': nan,
#  's_4264': 'C00957',
#  's_4265': 'C15521',
#  's_4267': 'C05122',
#  's_4269': 'C01861'}

# %% [markdown]
# # get plastics

# %%
# get all plastics

def get_plastics(df):
    
    csv_pathways = [i for i in df['INTERMEDIATES KEGG']]

    get_plastic = set()

    for i in csv_pathways:
        if i[0] not in get_plastic:
            get_plastic.add(i[0])

    plastics = list(get_plastic)
    return plastics

# %%
# apply to dataframe
plastics = get_plastics(df)
plastics
# Out:
# ['C06793']

# %%
# create plastic metabolites

## Propene

C11505_e = Metabolite(
    'C11505_e',
    formula = 'C3H6',
    name = 'Propene',
    compartment = 'e')

C11505_c = Metabolite(
    'C11505_c',
    formula = 'C3H6',
    name = 'Propene',
    compartment = 'c')


## Vinyl Chloride

C06793_e = Metabolite(
    'C06793_e',
    formula = 'C2H3Cl',
    name = 'Vinyl Chloride',
    compartment = 'e')

C06793_c = Metabolite(
    'C06793_c',
    formula = 'C2H3Cl',
    name = 'Vinyl Chloride',
    compartment = 'c')



## Ethylene

C06547_e = Metabolite(
    'C06547_e',
    formula = 'C2H4',
    name = 'Ethylene',
    compartment = 'e')

C06547_c = Metabolite(
    'C06547_c',
    formula = 'C2H4',
    name = 'Ethylene',
    compartment = 'c')



## Styrene

C07083_e = Metabolite(
    'C07083_e',
    formula = 'C8H8',
    name = 'Styrene',
    compartment = 'e')

C07083_c = Metabolite(
    'C07083_c',
    formula = 'C8H8',
    name = 'Styrene',
    compartment = 'c')


## Terephthalate 

C06337_e = Metabolite(
    'C06337_e',
    formula = 'C8H6O4',
    name = 'Terephthalate',
    compartment = 'e')

C06337_c = Metabolite(
    'C06337_c',
    formula = 'C8H6O4',
    name = 'Terephthalate',
    compartment = 'c')

# %%
# add plastic dictionary and add metabolites
plastic_dict = {}

plastic_dict['C11505_c'] = C11505_c
plastic_dict['C06793_c'] = C06793_c
plastic_dict['C06547_c'] = C06547_c
plastic_dict['C07083_c'] = C07083_c
plastic_dict['C06337_c'] = C06337_c

plastic_dict['C11505_e'] = C11505_e
plastic_dict['C06793_e'] = C06793_e
plastic_dict['C06547_e'] = C06547_e
plastic_dict['C07083_e'] = C07083_e
plastic_dict['C06337_e'] = C06337_e

# %%
# add plastic metabolites to dictionary

sk_dict['C11505_c'] = C11505_c
sk_dict['C06793_c'] = C06793_c
sk_dict['C06547_c'] = C06547_c
sk_dict['C07083_c'] = C07083_c
sk_dict['C06337_c'] = C06337_c

sk_dict['C11505_e'] = C11505_e
sk_dict['C06793_e'] = C06793_e
sk_dict['C06547_e'] = C06547_e
sk_dict['C07083_e'] = C07083_e
sk_dict['C06337_e'] = C06337_e

# %% [markdown]
# # run fva

# %%
# create algorithm calculating flux variability analysis
def fva(df, model, plastics):
    
    # get pathways from data frame
    pathways = [i for i in df['INTERMEDIATES KEGG']]
    
    
    
    # change name of plastics so that it matches version in dict
    for i in pathways:
        for e, compound in enumerate(i):
            if compound in plastics:
                i[e] = compound + '_c'
                
    
    
    # get list of cytosolic plastics (for later analysis)
    plastics_c = plastics.copy()

    for e, compound in enumerate(plastics_c):
        plastics_c[e] = compound + '_c'
     
    
            
    # get external plastics        
    e_plastics = plastics.copy()
    
    for i, plastic in enumerate(plastics):
        e_plastics[i] = plastic + '_e'
   
     
    
    # get list of products    
    products = [i[-1] for i in pathways]
    products = list(set(products))
    
    
    
    # get external products
    e_products = products.copy()
    
    for i, prod in enumerate(products):
        e_products[i] = prod + '_e'

    
    
    # get name of compounds that are not present in model
    get_compound = set()

    for pathway in pathways:
        for compound in pathway:
            if compound not in plastic_dict and compound not in sk_dict.values() and compound not in get_compound:
                get_compound.add(compound)

    get_compound = list(get_compound)
    
    

    # create names for missing metabolites
    compound_name = []

    for i, compound in enumerate(get_compound):
        comp = f"Metabolite_{i}"
        compound_name.append(comp)

        
    
    # take list of missing compounds, create metabolites and add to dictionaries
    metabolites = []
    met_dict = {}

    for compound in get_compound:
        new_met = Metabolite(compound, compartment='c')
        metabolites.append(new_met)
        sk_dict[compound] = new_met
        met_dict[compound] = new_met
        
    
    
    # add external plastics to list of pathways
    ext = []
    
    for pathway in pathways:
        if pathway[0] in plastics_c:
            index = plastics_c.index(pathway[0])
            ext.append(e_plastics[index])
        
        
    
    # add external products (weren't in list before) and add to model
    ext_p = []

    for i in e_products:
        new_prod = Metabolite(i, compartment='e')
        ext_p.append(new_prod)
        sk_dict[i] = new_prod

    model.add_metabolites(ext_p)
    
    
    # add external plastics to list of pathways
    ext2 = []
    
    for pathway in pathways:
        if pathway[-1] in products:
            index = products.index(pathway[-1])
            ext2.append(e_products[index])

    
            
    # add external lists to pathways     
    for i, item in enumerate(ext):
        pathways[i].insert(0, item)
    
    for j, item in enumerate(ext2):
        pathways[j].append(item)

        
        
    # transform coompounds in pathways list to metabolites
    for i in pathways:
        for j, item in enumerate(i):
            
            found = False
            

            if item in sk_dict:
                i[j] = sk_dict[item]
                found = True

            if not found and item in met_dict:
                i[j] = sk_dict[item]
                found = True

            if not found and item in sk_dict.values():
                temp = [key for key, value in sk_dict.items() if value == item]
                if temp:
                    temp2 = temp[0]
                    met = model.metabolites.get_by_id(temp2)
                    i[j] = met
                    found = True

            if not found:
                i[j] = item


    
    # separate list of pathways into twos (metabolite_1 --> metabolite 2)
                                        # (metabolite_2 --> metabolite_3)
                                        #  etc. 
    separated_pathways = []

    for i in pathways:
        pathway_pairs = []
        for j in range(len(i)-1):
            pair = [i[j], i[j+1]]
            pathway_pairs.append(pair)
        separated_pathways.append(pathway_pairs)
        
    
    
    # get number of reactions in pathway
    react_num = 0
    for i in separated_pathways:
        react_num += len(i)
        
        
     
    # create empty reactions using number above
    reactions = []

    for i in range(react_num):
        reaction = f"Reaction_{i}"

        new_reaction = Reaction(reaction)

        reactions.append(new_reaction)
        
        
        
    # create output list    
    grows = []
   

    
    # add metabolites to reactions and reaction to model
    for m, e in enumerate(separated_pathways):
        
        reactions_added = []
        
        for i, item in enumerate(e):
            
            # Add reaction to the model
            model.add_reactions([reactions[i]])
            
            # Add metabolites to reaction
            reactions[i].add_metabolites({
                    item[0]: -1.0,
                    item[1]: 1.0
                    })


            # for first and last reactions, create exchange reactions
            if i == 0 or i == len(e)-1:
                reactions[i].lower_bound = -10.0
                reactions[i].upper_bound = 1000.0
                
                
            # for all others, create normal (oneway) reactions
            else:
                reactions[i].lower_bound = 0.0
                reactions[i].upper_bound = 1000.0
 

            reactions_added.append(reactions[i])
            
            
            
        # run FBA on model    
        solution = model.optimize()
        
        fva = []
        
        # if cell can grow, store results
        if solution.status == 'optimal' and solution.objective_value > 0.000:

            grows.append(solution)
            
            
            fva_result = cobra.flux_analysis.flux_variability_analysis(model, model.reactions[:], fraction_of_optimum=0.9)
            pd.DataFrame.from_dict(fva_result).T
            
            return (solution, fva_result)
            
            #fva.append(fva_result)
            
            # remove all reactions and metabolites added within the loop
            model.remove_reactions(reactions_added)

            reactions = [reaction for reaction in reactions if reaction not in reactions_added]

            del reactions_added[:]
            
            

            

        else:
            
            # remove all reactions and metabolites added within the loop
            model.remove_reactions(reactions_added)

            reactions = [reaction for reaction in reactions if reaction not in reactions_added]

            del reactions_added[:]
            
    
    
    return (solution, fva_result)

# %% [markdown]
# # results

# %%
# call algorithm using highest pathway
a = fva(df, model, plastics)
a
# Out:
# (<Solution 9.379 at 0x7f9e3c294f10>,
#                 minimum      maximum
#  r_0001        0.000000    30.645530
#  r_0002        0.000000    30.645530
#  r_0003     -340.313838     0.000000
#  r_0004        0.000000    27.819494
#  r_0005        6.318542     7.020602
#  ...                ...          ...
#  Reaction_3  561.465198  1000.000000
#  Reaction_4    0.000000     0.000000
#  Reaction_5    0.000000     0.000000
#  Reaction_6    0.000000     0.000000
#  Reaction_7    0.000000     0.000000
#
#  [4071 rows x 2 columns])

# %%
# get dataframe from fva results

# %%
fva_result = a[1]
fva_result
# Out:
#                minimum      maximum
# r_0001        0.000000    30.645530
# r_0002        0.000000    30.645530
# r_0003     -340.313838     0.000000
# r_0004        0.000000    27.819494
# r_0005        6.318542     7.020602
# ...                ...          ...
# Reaction_3  561.465198  1000.000000
# Reaction_4    0.000000     0.000000
# Reaction_5    0.000000     0.000000
# Reaction_6    0.000000     0.000000
# Reaction_7    0.000000     0.000000
#
# [4071 rows x 2 columns]

# %% [raw]
# # get
# fva_20 = fva_result[:20]
# fva_20

# %% [raw]
# len(fva_20)

# %%
# top reactions form fba
top_20 = ['r_2100',
 'r_1667',
 'r_0438',
 'r_1277',
 'r_1110',
 'r_2096',
 'r_1245',
 'r_0226',
 'r_1763',
 'r_1632',
 'r_0165',
 'r_4575',
 'r_1761',
 'r_1762',
 'r_1696',
 'r_0439',
 'r_0658',
 'r_4574',
 'r_1672',
 'r_1697']

# %% [raw]
# top_20 = top_r[:20]
# top_20

# %% [raw]
# top = ['r_1654',
#  'r_0884',
#  'r_0471']

# %%
# generate new df wiht top 20 flux range
top_fva = fva_result.loc[top_20]
top_fva
# Out:
#             minimum      maximum
# r_2100 -1000.000000  -338.135323
# r_1667  -426.076688  1000.000000
# r_0438   878.498633  1000.000000
# r_1277   338.135323  1000.000000
# r_1110   753.888060   902.271452
# r_2096 -1000.000000  -314.474198
# r_1245   518.022302   940.861777
# r_0226   493.788199   821.027644
# r_1763 -1000.000000   173.478743
# r_1632 -1000.000000  -192.954838
# r_0165   192.954838  1000.000000
# r_4575   217.183992   694.292978
# r_1761     0.000000   629.278906
# r_1762     0.000000   629.278906
# r_1696  -747.724567  -240.559231
# r_0439   439.249316   500.000000
# r_0658     0.000000   615.845258
# r_4574    98.193937   715.483771
# r_1672   116.905550   625.670219
# r_1697   116.905550   625.670219

# %% [markdown]
# # load model data

# %%
# loading yeast metabolic model

model_path = '/Users/philine/Downloads/yeast-GEM-8.6.2/model/yeast-GEM.yml'

with open(model_path) as file:
    data = yaml.load(file, Loader=yaml.FullLoader)

# %%
# isolate reactions data
reactions = data[2]
reactions
# Out:
# ('reactions',
#  [[('id', 'r_0001'),
#    ('name', '(R)-lactate:ferricytochrome-c 2-oxidoreductase'),
#    ('metabolites',
#     [('s_0025', -1), ('s_0709', -2), ('s_0710', 2), ('s_1399', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule',
#     '(YDL174C and YEL039C) or (YDL174C and YJR048W) or (YEL039C and YEL071W) or (YEL071W and YJR048W)'),
#    ('eccodes', ['1.1.2.4', '1.1.99.-']),
#    ('subsystem', ['Pyruvate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'D_LACDcm'),
#      ('kegg.pathway', ['sce00620', 'sce00920']),
#      ('kegg.reaction', 'R00197'),
#      ('metanetx.reaction', 'MNXR138960'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0002'),
#    ('name', '(R)-lactate:ferricytochrome-c 2-oxidoreductase'),
#    ('metabolites',
#     [('s_0027', -1), ('s_0709', -2), ('s_0710', 2), ('s_1401', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', '(YDL178W and YEL039C) or (YDL178W and YJR048W)'),
#    ('eccodes', ['1.1.2.4', '1.1.99.-']),
#    ('subsystem', ['Pyruvate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'D_LACDm'),
#      ('kegg.pathway', ['sce00620', 'sce00920']),
#      ('kegg.reaction', 'R00197'),
#      ('metanetx.reaction', 'MNXR138960'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0003'),
#    ('name', '(R,R)-butanediol dehydrogenase'),
#    ('metabolites',
#     [('s_0020', 1),
#      ('s_0035', -1),
#      ('s_0794', 1),
#      ('s_1198', -1),
#      ('s_1203', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YAL060W'),
#    ('eccodes', '1.1.1.4'),
#    ('subsystem', ['Butanoate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'BTDD_RR'),
#      ('kegg.pathway', 'sce00650'),
#      ('kegg.reaction', 'R02946'),
#      ('metanetx.reaction', 'MNXR107844'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0004'),
#    ('name', '(S)-lactate:ferricytochrome-c 2-oxidoreductase'),
#    ('metabolites',
#     [('s_0063', -1), ('s_0709', -2), ('s_0710', 2), ('s_1399', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', '(YEL039C and YML054C) or (YJR048W and YML054C)'),
#    ('eccodes', '1.1.2.3'),
#    ('subsystem', ['Pyruvate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'L_LACD2cm'),
#      ('kegg.pathway', ['sce00620', 'sce00920']),
#      ('kegg.reaction', 'R00196'),
#      ('metanetx.reaction', 'MNXR138959'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0005'),
#    ('name', '1,3-beta-glucan synthase'),
#    ('metabolites',
#     [('s_0001', 1), ('s_0794', 1), ('s_1538', 1), ('s_1543', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule',
#     '(YPR165W and YLR342W) or (YPR165W and YGR032W) or (YPR165W and YMR306W)'),
#    ('eccodes', '2.4.1.34'),
#    ('subsystem', ['Starch and sucrose metabolism']),
#    ('annotation',
#     [('kegg.pathway', ['sce00500', 'sce04011']),
#      ('kegg.reaction', 'R03118'),
#      ('metanetx.reaction', 'MNXR143499'),
#      ('pubmed', '7649185'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0006'),
#    ('name', '1,6-beta-glucan synthase'),
#    ('metabolites',
#     [('s_0004', 1), ('s_0794', 1), ('s_1538', 1), ('s_1543', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR143W or YPR159W'),
#    ('subsystem', ['Starch and sucrose metabolism']),
#    ('annotation', [('pubmed', '8321211'), ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0007'),
#    ('name',
#     '1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino)imidazole-4-carboxamide isomerase'),
#    ('metabolites', [('s_0077', -1), ('s_0312', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YIL020C'),
#    ('eccodes', '5.3.1.16'),
#    ('subsystem', ['Histidine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PRMICI'),
#      ('kegg.pathway', ['sce00340', 'sce01110', 'sce01230']),
#      ('kegg.reaction', 'R04640'),
#      ('metanetx.reaction', 'MNXR103169'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0012'),
#    ('name', '1-pyrroline-5-carboxylate dehydrogenase'),
#    ('metabolites',
#     [('s_0119', -1),
#      ('s_0799', 1),
#      ('s_0807', -2),
#      ('s_0993', 1),
#      ('s_1200', -1),
#      ('s_1205', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YHR037W'),
#    ('eccodes', '1.2.1.88'),
#    ('subsystem', ['Alanine, aspartate and glutamate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'P5CDm'),
#      ('kegg.pathway', ['sce00250', 'sce00330']),
#      ('kegg.reaction', 'R00707'),
#      ('metanetx.reaction', 'MNXR102301'),
#      ('pubmed', '387737'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0013'),
#    ('name', '2,3-diketo-5-methylthio-1-phosphopentane degradation reaction'),
#    ('metabolites',
#     [('s_0294', 1),
#      ('s_0311', -1),
#      ('s_0722', 1),
#      ('s_0794', 6),
#      ('s_0803', -3),
#      ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YEL038W and YMR009W'),
#    ('eccodes', ['1.13.11.54', '3.1.3.77']),
#    ('subsystem', ['Cysteine and methionine metabolism']),
#    ('annotation',
#     [('kegg.pathway', 'sce00270'),
#      ('pubmed', '14506228'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0014'),
#    ('name',
#     "2,5-diamino-6-ribitylamino-4(3H)-pyrimidinone 5'-phosphate deaminase"),
#    ('metabolites',
#     [('s_0142', -1),
#      ('s_0313', 1),
#      ('s_0419', 1),
#      ('s_0794', -1),
#      ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOL066C'),
#    ('eccodes', ['3.5.4.26', '5.4.99.28']),
#    ('subsystem', ['Riboflavin metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'DRTPPD'),
#      ('kegg.pathway', 'sce00740'),
#      ('kegg.reaction', 'R09377'),
#      ('metanetx.reaction', 'MNXR112805'),
#      ('pubmed', '9068650'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0015'),
#    ('name',
#     "2,5-diamino-6-ribosylamino-4(3H)-pyrimidinone 5'-phosphate reductase (NADPH)"),
#    ('metabolites',
#     [('s_0141', -1),
#      ('s_0142', 1),
#      ('s_0794', -1),
#      ('s_1207', 1),
#      ('s_1212', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YBR153W'),
#    ('eccodes', '1.1.1.302'),
#    ('subsystem', ['Riboflavin metabolism']),
#    ('annotation',
#     [('kegg.pathway', 'sce00740'),
#      ('kegg.reaction', 'R09376'),
#      ('metanetx.reaction', 'MNXR112804'),
#      ('pubmed', '9068650'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0016'),
#    ('name', '2-aceto-2-hydroxybutanoate synthase'),
#    ('metabolites',
#     [('s_0039', 1),
#      ('s_0179', -1),
#      ('s_0460', 1),
#      ('s_0799', -1),
#      ('s_1401', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', '(YCL009C and YMR108W) or YMR108W'),
#    ('eccodes', '2.2.1.6'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'ACHBSm'),
#      ('kegg.pathway',
#       ['sce00290',
#        'sce00650',
#        'sce00660',
#        'sce00770',
#        'sce01110',
#        'sce01130',
#        'sce01210',
#        'sce01230']),
#      ('kegg.reaction', 'R08648'),
#      ('metanetx.reaction', 'MNXR95260'),
#      ('pubmed', '8972574'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0017'),
#    ('name',
#     '2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase'),
#    ('metabolites',
#     [('s_0006', 1),
#      ('s_0148', -1),
#      ('s_0424', 1),
#      ('s_0437', -1),
#      ('s_0799', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YNL256W'),
#    ('eccodes', ['2.5.1.15', '2.7.6.3', '4.1.2.25']),
#    ('subsystem', ['Folate biosynthesis']),
#    ('annotation',
#     [('kegg.pathway', 'sce00790'),
#      ('kegg.reaction', 'R03503'),
#      ('metanetx.reaction', 'MNXR100694'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0018'),
#    ('name', '2-aminoadipate transaminase'),
#    ('metabolites',
#     [('s_0176', -1), ('s_0180', 1), ('s_0953', 1), ('s_0991', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER152C or YGL202W or YJL060W'),
#    ('eccodes', ['2.6.1.39', '2.6.1.57', '2.6.1.7']),
#    ('subsystem', ['Lysine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'AATA'),
#      ('kegg.pathway',
#       ['sce00130',
#        'sce00270',
#        'sce00300',
#        'sce00350',
#        'sce00360',
#        'sce00380',
#        'sce00400',
#        'sce01110',
#        'sce01130',
#        'sce01210',
#        'sce01230']),
#      ('kegg.reaction', 'R01939'),
#      ('metanetx.reaction', 'MNXR95160'),
#      ('pubmed', ['10714900', '19342587']),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0019'),
#    ('name', '2-dehydropantoate 2-reductase'),
#    ('metabolites',
#     [('s_0030', 1),
#      ('s_0149', -1),
#      ('s_0794', -1),
#      ('s_1207', 1),
#      ('s_1212', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YHR063C'),
#    ('eccodes', '1.1.1.169'),
#    ('subsystem', ['Pantothenate and coa biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'DPR'),
#      ('kegg.pathway', ['sce00770', 'sce01110']),
#      ('kegg.reaction', 'R02472'),
#      ('metanetx.reaction', 'MNXR97779'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0020'),
#    ('name', '2-deoxy-D-arabino-heptulosonate 7-phosphate synthetase'),
#    ('metabolites',
#     [('s_0350', 1),
#      ('s_0552', -1),
#      ('s_0807', -1),
#      ('s_1326', 1),
#      ('s_1361', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR035W or YBR249C'),
#    ('eccodes', '2.5.1.54'),
#    ('subsystem', ['Phenylalanine, tyrosine and tryptophan biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'DDPAm'),
#      ('kegg.pathway', ['sce00400', 'sce01110', 'sce01130', 'sce01230']),
#      ('kegg.reaction', 'R01826'),
#      ('metanetx.reaction', 'MNXR97218'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0021'),
#    ('name', '2-hexaprenyl-6-methoxy-1,4-benzoquinone methyltransferase'),
#    ('metabolites',
#     [('s_0155', -1),
#      ('s_0156', 1),
#      ('s_0799', 1),
#      ('s_1415', 1),
#      ('s_1419', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule',
#     'YDR204W and YGR255C and YLR201C and YML110C and YOL096C and YOR125C'),
#    ('eccodes', ['1.14.13.-', '2.1.1.114', '2.1.1.201', '2.1.1.64', '2.7.-.-']),
#    ('subsystem', ['Ubiquinone and other terpenoid-quinone biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', '2HPMBQMTm'),
#      ('kegg.pathway', ['sce00130', 'sce01110']),
#      ('kegg.reaction', 'R04983'),
#      ('metanetx.reaction', 'MNXR109269'),
#      ('pubmed', '15792955'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0022'),
#    ('name', '2-hexaprenyl-6-methoxyphenol monooxygenase'),
#    ('metabolites',
#     [('s_0155', 1), ('s_0157', -1), ('s_0807', 1), ('s_1278', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule',
#     'YDR204W and YGR255C and YLR201C and YML110C and YOL096C and YOR125C'),
#    ('eccodes', ['1.14.13.-', '2.1.1.114', '2.1.1.201', '2.1.1.64', '2.7.-.-']),
#    ('subsystem', ['Ubiquinone and other terpenoid-quinone biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', '2HP6MPMOm'),
#      ('kegg.pathway', ['sce00130', 'sce01110']),
#      ('kegg.reaction', 'R04982'),
#      ('metanetx.reaction', 'MNXR109268'),
#      ('pubmed', '15792955'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0023'),
#    ('name', '2-isopropylmalate hydratase'),
#    ('metabolites', [('s_0162', 1), ('s_0165', -1), ('s_0803', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGL009C'),
#    ('eccodes', '4.2.1.33'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'IPPMIb'),
#      ('kegg.pathway', ['sce00290', 'sce01110', 'sce01210', 'sce01230']),
#      ('kegg.reaction', 'R03968'),
#      ('metanetx.reaction', 'MNXR100826'),
#      ('pubmed', '3071717'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0024'),
#    ('name', '2-isopropylmalate synthase'),
#    ('metabolites',
#     [('s_0162', 1),
#      ('s_0232', -1),
#      ('s_0373', -1),
#      ('s_0529', 1),
#      ('s_0794', 1),
#      ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YNL104C or YOR108W'),
#    ('eccodes', '2.3.3.13'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'IPPS'),
#      ('kegg.pathway',
#       ['sce00290', 'sce00620', 'sce01110', 'sce01210', 'sce01230']),
#      ('kegg.reaction', 'R01213'),
#      ('metanetx.reaction', 'MNXR100879'),
#      ('pubmed', '6090272'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0025'),
#    ('name', '2-isopropylmalate synthase'),
#    ('metabolites',
#     [('s_0164', 1),
#      ('s_0233', -1),
#      ('s_0376', -1),
#      ('s_0532', 1),
#      ('s_0799', 1),
#      ('s_0807', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YNL104C'),
#    ('eccodes', '2.3.3.13'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'IPPSm'),
#      ('kegg.pathway',
#       ['sce00290', 'sce00620', 'sce01110', 'sce01210', 'sce01230']),
#      ('kegg.reaction', 'R01213'),
#      ('metanetx.reaction', 'MNXR100879'),
#      ('pubmed', '6090272'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0026'),
#    ('name', '2-keto-4-methylthiobutyrate transamination'),
#    ('metabolites',
#     [('s_0180', 1), ('s_0294', -1), ('s_0991', -1), ('s_1029', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YHR208W or YJR148W or YGL202W or YHR137W'),
#    ('subsystem', ['Cysteine and methionine metabolism']),
#    ('annotation',
#     [('kegg.reaction', 'R07396'),
#      ('metanetx.reaction', 'MNXR95923'),
#      ('pubmed', '14506228'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0027'),
#    ('name', '2-methylcitrate dehydratase'),
#    ('metabolites', [('s_0454', 1), ('s_0807', 1), ('s_0834', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR234W'),
#    ('eccodes', '4.2.1.36'),
#    ('subsystem', ['Lysine metabolism']),
#    ('annotation',
#     [('kegg.pathway', ['sce00300', 'sce01130', 'sce01210', 'sce01230']),
#      ('kegg.reaction', 'R03444'),
#      ('metanetx.reaction', 'MNXR141287'),
#      ('pubmed', '5908136'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0028'),
#    ('name', '2-methylcitrate synthase'),
#    ('metabolites',
#     [('s_0174', 1),
#      ('s_0532', 1),
#      ('s_0799', 1),
#      ('s_0807', -1),
#      ('s_1273', -1),
#      ('s_1382', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YPR001W'),
#    ('eccodes', '2.3.3.1'),
#    ('subsystem', ['Propanoate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'MCITSm'),
#      ('kegg.pathway',
#       ['sce00020',
#        'sce00630',
#        'sce01110',
#        'sce01130',
#        'sce01200',
#        'sce01210',
#        'sce01230']),
#      ('kegg.reaction', 'R00931'),
#      ('metanetx.reaction', 'MNXR101417'),
#      ('pubmed', '16332871'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0029'),
#    ('name', '2-oxo-4-methyl-3-carboxypentanoate decarboxylation'),
#    ('metabolites',
#     [('s_0010', -1), ('s_0291', 1), ('s_0456', 1), ('s_0794', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YJR148W'),
#    ('eccodes', '2.6.1.42'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'OMCDC'),
#      ('kegg.pathway',
#       ['sce00270',
#        'sce00280',
#        'sce00290',
#        'sce00770',
#        'sce01110',
#        'sce01130',
#        'sce01210',
#        'sce01230']),
#      ('kegg.reaction', 'R01652'),
#      ('metanetx.reaction', 'MNXR102180'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0030'),
#    ('name', '2-oxo-4-methyl-3-carboxypentanoate decarboxylation'),
#    ('metabolites',
#     [('s_0011', -1), ('s_0292', 1), ('s_0460', 1), ('s_0799', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YHR208W'),
#    ('eccodes', '2.6.1.42'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'OMCDCm'),
#      ('kegg.pathway',
#       ['sce00270',
#        'sce00280',
#        'sce00290',
#        'sce00770',
#        'sce01110',
#        'sce01130',
#        'sce01210',
#        'sce01230']),
#      ('kegg.reaction', 'R01652'),
#      ('metanetx.reaction', 'MNXR102180'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0032'),
#    ('name', "3',5'-bisphosphate nucleotidase"),
#    ('metabolites',
#     [('s_0390', -1), ('s_0423', 1), ('s_0803', -1), ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOL064C'),
#    ('eccodes', '3.1.3.7'),
#    ('subsystem', ['Sulfur metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'BPNT'),
#      ('kegg.pathway', ['sce00920', 'sce01130']),
#      ('kegg.reaction', 'R00188'),
#      ('metanetx.reaction', 'MNXR96321'),
#      ('pubmed', '7809627'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0033'),
#    ('name', "3',5'-cyclic-nucleotide phosphodiesterase"),
#    ('metabolites',
#     [('s_0192', -1), ('s_0423', 1), ('s_0794', 1), ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGL248W or YOR360C'),
#    ('eccodes', ['3.1.4.17', '3.1.4.53']),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PDE1'),
#      ('kegg.pathway', 'sce00230'),
#      ('kegg.reaction', 'R00191'),
#      ('metanetx.reaction', 'MNXR95886'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0034'),
#    ('name', "3',5'-cyclic-nucleotide phosphodiesterase"),
#    ('metabolites',
#     [('s_0194', -1), ('s_0584', 1), ('s_0794', 1), ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR360C'),
#    ('eccodes', '3.1.4.53'),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PDE2'),
#      ('kegg.pathway', 'sce00230'),
#      ('metanetx.reaction', 'MNXR136084'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0035'),
#    ('name', "3',5'-cyclic-nucleotide phosphodiesterase"),
#    ('metabolites',
#     [('s_0196', -1), ('s_0794', 1), ('s_0803', -1), ('s_0849', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR360C'),
#    ('eccodes', '3.1.4.53'),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PDE3'),
#      ('kegg.pathway', 'sce00230'),
#      ('metanetx.reaction', 'MNXR136083'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0036'),
#    ('name', "3',5'-cyclic-nucleotide phosphodiesterase"),
#    ('metabolites',
#     [('s_0195', -1), ('s_0782', 1), ('s_0794', 1), ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR360C'),
#    ('eccodes', '3.1.4.53'),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PDE4'),
#      ('kegg.pathway', 'sce00230'),
#      ('kegg.reaction', 'R01234'),
#      ('metanetx.reaction', 'MNXR100078'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0037'),
#    ('name', "3',5'-cyclic-nucleotide phosphodiesterase"),
#    ('metabolites',
#     [('s_0193', -1), ('s_0526', 1), ('s_0794', 1), ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR360C'),
#    ('eccodes', '3.1.4.53'),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PDE5'),
#      ('kegg.pathway', 'sce00230'),
#      ('metanetx.reaction', 'MNXR136082'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0038'),
#    ('name', '3,4-dihydroxy-2-butanone-4-phosphate synthase'),
#    ('metabolites',
#     [('s_0158', 1), ('s_0577', -1), ('s_0722', 1), ('s_0794', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR487C'),
#    ('eccodes', '4.1.99.12'),
#    ('subsystem', ['Riboflavin metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'DB4PS'),
#      ('kegg.pathway', ['sce00740', 'sce01110']),
#      ('kegg.reaction', 'R07281'),
#      ('metanetx.reaction', 'MNXR97178'),
#      ('pubmed', '12595523'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0039'),
#    ('name', '3-dehydroquinate dehydratase'),
#    ('metabolites', [('s_0210', -1), ('s_0211', 1), ('s_0803', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR127W'),
#    ('eccodes', ['1.1.1.25', '2.5.1.19', '2.7.1.71', '4.2.1.10', '4.2.3.4']),
#    ('subsystem', ['Phenylalanine, tyrosine and tryptophan biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'DHQTi'),
#      ('kegg.pathway', ['sce00400', 'sce01110', 'sce01130', 'sce01230']),
#      ('kegg.reaction', 'R03084'),
#      ('metanetx.reaction', 'MNXR97449'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0040'),
#    ('name', '3-dehydroquinate synthase'),
#    ('metabolites', [('s_0210', 1), ('s_0349', -1), ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR127W'),
#    ('eccodes', ['1.1.1.25', '2.5.1.19', '2.7.1.71', '4.2.1.10', '4.2.3.4']),
#    ('subsystem', ['Phenylalanine, tyrosine and tryptophan biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'DHQS'),
#      ('kegg.pathway', ['sce00400', 'sce01110', 'sce01130', 'sce01230']),
#      ('kegg.reaction', 'R03083'),
#      ('metanetx.reaction', 'MNXR97447'),
#      ('pubmed', '6355828'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0041'),
#    ('name', '3-dehydrosphinganine reductase'),
#    ('metabolites',
#     [('s_0231', -1),
#      ('s_0795', -1),
#      ('s_1208', 1),
#      ('s_1213', -1),
#      ('s_1445', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YBR265W'),
#    ('eccodes', '1.1.1.102'),
#    ('subsystem', ['Sphingolipid metabolism']),
#    ('annotation',
#     [('kegg.pathway', 'sce00600'),
#      ('kegg.reaction', 'R02978'),
#      ('metanetx.reaction', 'MNXR94866'),
#      ('pubmed', ['18296751', '9804843']),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0042'),
#    ('name', '3-deoxy-D-arabino-heptulosonate 7-phosphate synthetase'),
#    ('metabolites',
#     [('s_0349', 1),
#      ('s_0551', -1),
#      ('s_0803', -1),
#      ('s_1322', 1),
#      ('s_1360', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YBR249C or YDR035W'),
#    ('eccodes', '2.5.1.54'),
#    ('subsystem', ['Phenylalanine, tyrosine and tryptophan biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'DDPA'),
#      ('kegg.pathway', ['sce00400', 'sce01110', 'sce01130', 'sce01230']),
#      ('kegg.reaction', 'R01826'),
#      ('metanetx.reaction', 'MNXR97218'),
#      ('pubmed', '2880280'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0043'),
#    ('name', '3-hexaprenyl-4,5-dihydroxybenzoate hydroxylase'),
#    ('metabolites', [('s_0212', 1), ('s_0215', -1), ('s_1275', -0.5)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YPL252C or YDR376W'),
#    ('subsystem', ['Ubiquinone and other terpenoid-quinone biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', '3OPHB5Hm'),
#      ('kegg.reaction', 'R06865'),
#      ('metanetx.reaction', 'MNXR110601'),
#      ('pubmed', '15792955'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0044'),
#    ('name', '3-hexaprenyl-4-hydroxy-5-methoxybenzoate decarboxylase'),
#    ('metabolites',
#     [('s_0157', 1), ('s_0214', -1), ('s_0460', 1), ('s_0799', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR538W and YDR539W'),
#    ('subsystem', ['Ubiquinone and other terpenoid-quinone biosynthesis']),
#    ('annotation',
#     [('kegg.reaction', 'R06866'),
#      ('metanetx.reaction', 'MNXR94901'),
#      ('pubmed', '15792955'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0045'),
#    ('name', '3-hydroxy-L-kynurenine hydrolase'),
#    ('metabolites',
#     [('s_0222', -1),
#      ('s_0224', 1),
#      ('s_0794', 1),
#      ('s_0803', -1),
#      ('s_0955', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR231C'),
#    ('eccodes', '3.7.1.3'),
#    ('subsystem', ['Tryptophan metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'HKYNH'),
#      ('kegg.pathway', 'sce00380'),
#      ('kegg.reaction', 'R02668'),
#      ('metanetx.reaction', 'MNXR100656'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0057'),
#    ('name', '3-hydroxyacyl-CoA dehydrogenase (3-oxotetradecanoyl-CoA)'),
#    ('metabolites',
#     [('s_0054', -1),
#      ('s_0257', 1),
#      ('s_0801', 1),
#      ('s_1202', -1),
#      ('s_1206', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YKR009C'),
#    ('eccodes', ['1.1.1.n12', '4.2.1.119']),
#    ('subsystem', ['Fatty acid degradation']),
#    ('annotation',
#     [('bigg.reaction', 'HACD6p'),
#      ('kegg.reaction', 'R04739'),
#      ('metanetx.reaction', 'MNXR100547'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0058'),
#    ('name', '3-hydroxyanthranilate 3,4-dioxygenase'),
#    ('metabolites', [('s_0147', 1), ('s_0224', -1), ('s_1275', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YJR025C'),
#    ('eccodes', '1.13.11.6'),
#    ('subsystem', ['Tryptophan metabolism']),
#    ('annotation',
#     [('bigg.reaction', '3HAO'),
#      ('kegg.pathway', 'sce00380'),
#      ('kegg.reaction', 'R02665'),
#      ('metanetx.reaction', 'MNXR94889'),
#      ('pubmed', '9539135'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0059'),
#    ('name', '3-isopropylmalate 3-methyltransferase'),
#    ('metabolites',
#     [('s_0009', -1), ('s_0217', 1), ('s_1413', 1), ('s_1416', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER175C'),
#    ('eccodes', '2.1.1.145'),
#    ('subsystem', ['Complex alcohol metabolism']),
#    ('annotation', [('pubmed', '15147181'), ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0060'),
#    ('name', '3-isopropylmalate dehydratase'),
#    ('metabolites', [('s_0009', -1), ('s_0165', 1), ('s_0803', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGL009C'),
#    ('eccodes', '4.2.1.33'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'IPPMIa'),
#      ('kegg.pathway', ['sce00290', 'sce01110', 'sce01210', 'sce01230']),
#      ('kegg.reaction', 'R04001'),
#      ('metanetx.reaction', 'MNXR100827'),
#      ('pubmed', '3071717'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0061'),
#    ('name', '3-isopropylmalate dehydrogenase'),
#    ('metabolites',
#     [('s_0009', -1),
#      ('s_0010', 1),
#      ('s_0794', 1),
#      ('s_1198', -1),
#      ('s_1203', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YCL018W'),
#    ('eccodes', '1.1.1.85'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'IPMD'),
#      ('kegg.pathway',
#       ['sce00290', 'sce00660', 'sce01110', 'sce01210', 'sce01230']),
#      ('kegg.reaction', 'R04426'),
#      ('metanetx.reaction', 'MNXR100878'),
#      ('pubmed', '6297759'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0062'),
#    ('name', '3-methyl-2-oxobutanoate decarboxylase'),
#    ('metabolites',
#     [('s_0232', -1), ('s_0456', 1), ('s_0794', -1), ('s_0937', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR087C or YLR044C or YLR134W'),
#    ('eccodes', ['4.1.1.-', '4.1.1.1', '4.1.1.43', '4.1.1.74']),
#    ('subsystem', ['Complex alcohol metabolism']),
#    ('annotation',
#     [('bigg.reaction', '3MOBDC'),
#      ('kegg.pathway', ['sce00010', 'sce01110', 'sce01130']),
#      ('metanetx.reaction', 'MNXR94922'),
#      ('pubmed', '12902239'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0063'),
#    ('name', '3-methyl-2-oxobutanoate hydroxymethyltransferase'),
#    ('metabolites',
#     [('s_0150', 1),
#      ('s_0233', -1),
#      ('s_0307', -1),
#      ('s_0807', -1),
#      ('s_1488', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YBR176W'),
#    ('eccodes', '2.1.2.11'),
#    ('subsystem', ['Pantothenate and coa biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'MTMOHT'),
#      ('kegg.pathway', ['sce00770', 'sce01110']),
#      ('kegg.reaction', 'R01226'),
#      ('metanetx.reaction', 'MNXR101702'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0064'),
#    ('name', '3-methyl-2-oxopentanoate decarboxylase'),
#    ('metabolites',
#     [('s_0056', -1), ('s_0166', 1), ('s_0456', 1), ('s_0794', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDL080C or YGR087C or YLR044C or YLR134W'),
#    ('eccodes', ['4.1.1.-', '4.1.1.1', '4.1.1.43', '4.1.1.74']),
#    ('subsystem', ['Complex alcohol metabolism']),
#    ('annotation',
#     [('bigg.reaction', '3MOPDC'),
#      ('kegg.pathway', ['sce00010', 'sce01110', 'sce01130']),
#      ('kegg.reaction', 'R03894'),
#      ('metanetx.reaction', 'MNXR94925'),
#      ('pubmed', '12902239'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0065'),
#    ('name', '3-phosphoshikimate 1-carboxyvinyltransferase'),
#    ('metabolites',
#     [('s_0261', -1), ('s_0324', 1), ('s_1322', 1), ('s_1360', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR127W'),
#    ('eccodes', ['1.1.1.25', '2.5.1.19', '2.7.1.71', '4.2.1.10', '4.2.3.4']),
#    ('subsystem', ['Phenylalanine, tyrosine and tryptophan biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'PSCVT'),
#      ('kegg.pathway', ['sce00400', 'sce01110', 'sce01130', 'sce01230']),
#      ('kegg.reaction', 'R03460'),
#      ('metanetx.reaction', 'MNXR103226'),
#      ('pubmed', '6355828'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0066'),
#    ('name', '4-amino-4-deoxychorismate synthase'),
#    ('metabolites',
#     [('s_0269', 1), ('s_0515', -1), ('s_0991', 1), ('s_0999', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YNR033W'),
#    ('eccodes', '2.6.1.85'),
#    ('subsystem', ['Folate biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'ADCS'),
#      ('kegg.pathway', 'sce00790'),
#      ('kegg.reaction', 'R01716'),
#      ('metanetx.reaction', 'MNXR95440'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0067'),
#    ('name', '4-aminobenzoate synthase'),
#    ('metabolites',
#     [('s_0269', -1), ('s_0271', 1), ('s_0794', 1), ('s_1399', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YMR289W'),
#    ('eccodes', '4.1.3.38'),
#    ('subsystem', ['Folate biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', 'ADCL'),
#      ('kegg.reaction', 'R05553'),
#      ('metanetx.reaction', 'MNXR95436'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0068'),
#    ('name', '4-aminobutyrate transaminase'),
#    ('metabolites',
#     [('s_0180', -1), ('s_0734', -1), ('s_0991', 1), ('s_1461', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR019W'),
#    ('eccodes', '2.6.1.19'),
#    ('subsystem', ['Alanine, aspartate and glutamate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'ABTA'),
#      ('kegg.pathway',
#       ['sce00250', 'sce00280', 'sce00410', 'sce00640', 'sce00650']),
#      ('kegg.reaction', 'R01648'),
#      ('metanetx.reaction', 'MNXR95186'),
#      ('pubmed', '10590462'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0069'),
#    ('name', '4-hydroxy-L-threonine synthase'),
#    ('metabolites',
#     [('s_0264', -1), ('s_0285', 1), ('s_0803', -1), ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YCR053W'),
#    ('eccodes', '4.2.3.1'),
#    ('subsystem', ['Vitamin b6 metabolism']),
#    ('annotation',
#     [('bigg.reaction', '4HTHRS'),
#      ('kegg.pathway', ['sce00260', 'sce00750', 'sce01110', 'sce01230']),
#      ('kegg.reaction', 'R05086'),
#      ('metanetx.reaction', 'MNXR95024'),
#      ('pubmed', '8082795'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0070'),
#    ('name', '4-hydroxybenzoate formation'),
#    ('metabolites',
#     [('s_0287', 1),
#      ('s_0290', -1),
#      ('s_0532', 1),
#      ('s_0799', 1),
#      ('s_0807', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('subsystem', ['Ubiquinone and other terpenoid-quinone biosynthesis']),
#    ('annotation',
#     [('bigg.reaction', '4HBZFm'),
#      ('kegg.reaction', 'R01301'),
#      ('metanetx.reaction', 'MNXR95011'),
#      ('pubmed', '11583838'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 0)],
#   [('id', 'r_0072'),
#    ('name', '4-methyl-2-oxopentanoate decarboxylase'),
#    ('metabolites',
#     [('s_0234', 1), ('s_0291', -1), ('s_0456', 1), ('s_0794', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDL080C'),
#    ('eccodes', '4.1.1.-'),
#    ('subsystem', ['Complex alcohol metabolism']),
#    ('annotation',
#     [('bigg.reaction', '4MOPDC'),
#      ('kegg.pathway', ['sce00010', 'sce01110', 'sce01130']),
#      ('metanetx.reaction', 'MNXR137950'),
#      ('pubmed', '12902239'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0073'),
#    ('name', '4PP-IP5 depyrophosphorylation to IP6'),
#    ('metabolites',
#     [('s_0279', -1),
#      ('s_0794', 1),
#      ('s_0803', -1),
#      ('s_1158', 1),
#      ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR410W or YOR163W'),
#    ('eccodes', ['2.7.4.21', '2.7.4.24', '3.6.1.52', '3.6.1.60']),
#    ('subsystem', ['Inositol phosphate metabolism']),
#    ('annotation',
#     [('kegg.reaction', 'R05779'),
#      ('metanetx.reaction', 'MNXR103044'),
#      ('pubmed', '17412958'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0074'),
#    ('name', '4PP-IP5 pyrophosphorylation to 4,5-PP2-IP4'),
#    ('metabolites',
#     [('s_0263', 1),
#      ('s_0279', -1),
#      ('s_0394', 1),
#      ('s_0434', -1),
#      ('s_0794', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR017C'),
#    ('eccodes', '2.7.4.21'),
#    ('subsystem', ['Phosphatidylinositol signaling system']),
#    ('annotation',
#     [('kegg.pathway', ['sce04070', 'sce04138']),
#      ('pubmed', '17412958'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0075'),
#    ('name', "5'-methylthioadenosine phosphorylase"),
#    ('metabolites',
#     [('s_0303', -1), ('s_0383', 1), ('s_1322', -1), ('s_1422', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR017W'),
#    ('eccodes', '2.4.2.28'),
#    ('subsystem', ['Cysteine and methionine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'MTAP'),
#      ('kegg.pathway', 'sce00270'),
#      ('kegg.reaction', 'R01402'),
#      ('metanetx.reaction', 'MNXR101745'),
#      ('pubmed', '14506228'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0076'),
#    ('name', "5'-nucleotidase (CMP)"),
#    ('metabolites',
#     [('s_0526', -1), ('s_0543', 1), ('s_0803', -1), ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER037W or YGL224C'),
#    ('eccodes', '3.1.3.-'),
#    ('subsystem', ['Nicotinate and nicotinamide metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'NTD4'),
#      ('kegg.pathway', 'sce00760'),
#      ('kegg.reaction', 'R00511'),
#      ('metanetx.reaction', 'MNXR102034'),
#      ('pubmed', ['11934891', '23670538']),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0077'),
#    ('name', "5'-nucleotidase (IMP)"),
#    ('metabolites',
#     [('s_0803', -1), ('s_0849', -1), ('s_0856', 1), ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR155C'),
#    ('eccodes', '3.1.3.99'),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'NTD11'),
#      ('kegg.pathway', ['sce00230', 'sce00760']),
#      ('kegg.reaction', 'R01126'),
#      ('metanetx.reaction', 'MNXR102030'),
#      ('pubmed', '12735798'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0078'),
#    ('name', "5'-nucleotidase (UMP)"),
#    ('metabolites',
#     [('s_0803', -1), ('s_1322', 1), ('s_1545', -1), ('s_1556', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER037W or YGL224C'),
#    ('eccodes', '3.1.3.-'),
#    ('subsystem', ['Nicotinate and nicotinamide metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'NTD2'),
#      ('kegg.pathway', 'sce00760'),
#      ('kegg.reaction', 'R00963'),
#      ('metanetx.reaction', 'MNXR102032'),
#      ('pubmed', ['11934891', '23670538']),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0079'),
#    ('name', "5'-phosphoribosylformyl glycinamidine synthetase"),
#    ('metabolites',
#     [('s_0301', -1),
#      ('s_0302', 1),
#      ('s_0394', 1),
#      ('s_0434', -1),
#      ('s_0794', 1),
#      ('s_0803', -1),
#      ('s_0991', 1),
#      ('s_0999', -1),
#      ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR061C'),
#    ('eccodes', '6.3.5.3'),
#    ('subsystem', ['Purine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PRFGS'),
#      ('kegg.pathway', ['sce00230', 'sce01110', 'sce01130']),
#      ('kegg.reaction', 'R04463'),
#      ('metanetx.reaction', 'MNXR108904'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0080'),
#    ('name', '5,10-methylenetetrahydrofolate reductase (NADPH)'),
#    ('metabolites',
#     [('s_0306', -1),
#      ('s_0322', 1),
#      ('s_0794', -1),
#      ('s_1207', 1),
#      ('s_1212', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGL125W or YPL023C'),
#    ('eccodes', '1.5.1.20'),
#    ('subsystem', ['One carbon pool by folate']),
#    ('annotation',
#     [('bigg.reaction', 'MTHFR3'),
#      ('kegg.pathway', ['sce00670', 'sce01200']),
#      ('kegg.reaction', 'R01224'),
#      ('metanetx.reaction', 'MNXR101752'),
#      ('pubmed', '21623372'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0081'),
#    ('name', '5-aminolevulinate synthase'),
#    ('metabolites',
#     [('s_0317', 1),
#      ('s_0460', 1),
#      ('s_0532', 1),
#      ('s_0799', -1),
#      ('s_1005', -1),
#      ('s_1464', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR232W'),
#    ('eccodes', '2.3.1.37'),
#    ('subsystem', ['Porphyrin and chlorophyll metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'ALASm'),
#      ('kegg.pathway', ['sce00260', 'sce00860', 'sce01110']),
#      ('kegg.reaction', 'R00830'),
#      ('metanetx.reaction', 'MNXR95695'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0082'),
#    ('name',
#     '5-diphosphoinositol-1,2,3,4,6-pentakisphosphate diphosphohydrolase'),
#    ('metabolites',
#     [('s_0318', -1),
#      ('s_0794', 1),
#      ('s_0803', -1),
#      ('s_1158', 1),
#      ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR163W'),
#    ('eccodes', ['3.6.1.52', '3.6.1.60']),
#    ('subsystem', ['Inositol phosphate metabolism']),
#    ('annotation',
#     [('kegg.reaction', 'R05779'),
#      ('metanetx.reaction', 'MNXR103044'),
#      ('pubmed', '10419486'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0083'),
#    ('name', '5-diphosphoinositol-1,2,3,4,6-pentakisphosphate synthase'),
#    ('metabolites',
#     [('s_0318', 1), ('s_0394', 1), ('s_0434', -1), ('s_1158', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR017C'),
#    ('eccodes', '2.7.4.21'),
#    ('subsystem', ['Phosphatidylinositol signaling system']),
#    ('annotation',
#     [('kegg.pathway', ['sce04070', 'sce04138']),
#      ('kegg.reaction', 'R09087'),
#      ('metanetx.reaction', 'MNXR101584'),
#      ('pubmed', '11956213'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0084'),
#    ('name', '5-formethyltetrahydrofolate cyclo-ligase'),
#    ('metabolites',
#     [('s_0304', 1),
#      ('s_0319', -1),
#      ('s_0394', 1),
#      ('s_0434', -1),
#      ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER183C'),
#    ('eccodes', '6.3.3.2'),
#    ('subsystem', ['One carbon pool by folate']),
#    ('annotation',
#     [('bigg.reaction', 'FTHFCL'),
#      ('kegg.pathway', 'sce00670'),
#      ('kegg.reaction', 'R02301'),
#      ('metanetx.reaction', 'MNXR99668'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0085'),
#    ('name',
#     '5-methyltetrahydropteroyltriglutamate-homocysteine S-methyltransferase'),
#    ('metabolites',
#     [('s_0323', -1), ('s_1012', -1), ('s_1029', 1), ('s_1486', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER091C'),
#    ('eccodes', '2.1.1.14'),
#    ('subsystem', ['Cysteine and methionine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'MHPGLUT'),
#      ('kegg.pathway', ['sce00270', 'sce00450', 'sce01110', 'sce01230']),
#      ('kegg.reaction', 'R04405'),
#      ('metanetx.reaction', 'MNXR101555'),
#      ('pubmed', '3542720'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0086'),
#    ('name', '5-methylthio-5-deoxy-D-ribulose 1-phosphate dehydratase'),
#    ('metabolites', [('s_0311', 1), ('s_0803', 1), ('s_1423', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YJR024C'),
#    ('subsystem', ['Cysteine and methionine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'MDRPD'),
#      ('kegg.reaction', 'R07392'),
#      ('metanetx.reaction', 'MNXR125830'),
#      ('pubmed', '14506228'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0087'),
#    ('name', '5-methylthioribose-1-phosphate isomerase'),
#    ('metabolites', [('s_1422', -1), ('s_1423', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YPR118W'),
#    ('subsystem', ['Cysteine and methionine metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'MTRI'),
#      ('kegg.reaction', 'R04420'),
#      ('metanetx.reaction', 'MNXR101759'),
#      ('pubmed', '14506228'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0088'),
#    ('name', '5PP-IP5 pyrophosphorylation to 4,5-PP2-IP4'),
#    ('metabolites',
#     [('s_0263', 1),
#      ('s_0318', -1),
#      ('s_0794', -2),
#      ('s_0803', 1),
#      ('s_1322', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR410W'),
#    ('eccodes', ['2.7.4.21', '2.7.4.24']),
#    ('subsystem', ['Inositol phosphate metabolism']),
#    ('annotation', [('pubmed', '17412958'), ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0089'),
#    ('name', '5PP-IP5 pyrophosphorylation to 5,6-PP2-IP4'),
#    ('metabolites',
#     [('s_0309', 1),
#      ('s_0318', -1),
#      ('s_0794', -2),
#      ('s_0803', 1),
#      ('s_1322', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR410W'),
#    ('eccodes', ['2.7.4.21', '2.7.4.24']),
#    ('subsystem', ['Inositol phosphate metabolism']),
#    ('annotation', [('pubmed', '17412958'), ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0090'),
#    ('name', '6-phosphofructo-2-kinase'),
#    ('metabolites',
#     [('s_0394', 1),
#      ('s_0434', -1),
#      ('s_0442', 1),
#      ('s_0557', -1),
#      ('s_0794', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YIL107C or YOL136C'),
#    ('eccodes', '2.7.1.105'),
#    ('subsystem', ['Fructose and mannose metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'PFK26'),
#      ('kegg.pathway', 'sce00051'),
#      ('metanetx.reaction', 'MNXR124534'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 2)],
#   [('id', 'r_0091'),
#    ('name', '6-phosphogluconolactonase'),
#    ('metabolites',
#     [('s_0335', -1), ('s_0340', 1), ('s_0794', 1), ('s_0803', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR248W or YHR163W'),
#    ('eccodes', '3.1.1.31'),
#    ('subsystem', ['Pentose phosphate pathway']),
#    ('annotation',
#     [('bigg.reaction', 'PGL'),
#      ('kegg.pathway', ['sce00030', 'sce01110', 'sce01130', 'sce01200']),
#      ('kegg.reaction', 'R02035'),
#      ('metanetx.reaction', 'MNXR102539'),
#      ('pubmed', '14454532'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0092'),
#    ('name', '6PP-IP5 depyrophosphorylation to IP6'),
#    ('metabolites',
#     [('s_0333', -1),
#      ('s_0794', 1),
#      ('s_0803', -1),
#      ('s_1158', 1),
#      ('s_1322', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR410W or YOR163W'),
#    ('eccodes', ['2.7.4.21', '2.7.4.24', '3.6.1.52', '3.6.1.60']),
#    ('subsystem', ['Inositol phosphate metabolism']),
#    ('annotation',
#     [('kegg.reaction', 'R05779'),
#      ('metanetx.reaction', 'MNXR103044'),
#      ('pubmed', '17412958'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0093'),
#    ('name', '6PP-IP5 pyrophosphorylation to 5,6-PP2-IP4'),
#    ('metabolites',
#     [('s_0309', 1),
#      ('s_0333', -1),
#      ('s_0394', 1),
#      ('s_0434', -1),
#      ('s_0794', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR017C'),
#    ('eccodes', '2.7.4.21'),
#    ('subsystem', ['Phosphatidylinositol signaling system']),
#    ('annotation',
#     [('kegg.pathway', ['sce04070', 'sce04138']),
#      ('pubmed', '17412958'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0094'),
#    ('name', '8-amino-7-oxononanoate synthase'),
#    ('metabolites',
#     [('s_0352', 1),
#      ('s_0456', 1),
#      ('s_0529', 1),
#      ('s_0794', -1),
#      ('s_0955', -1),
#      ('s_1368', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('subsystem', ['Biotin metabolism']),
#    ('annotation',
#     [('kegg.reaction', 'R03210'),
#      ('metanetx.reaction', 'MNXR95854'),
#      ('pubmed', '16269718'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0095'),
#    ('name', 'acetaldehyde condensation'),
#    ('metabolites', [('s_0020', 1), ('s_0359', -2)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR087C or YLR044C or YLR134W'),
#    ('eccodes', ['4.1.1.-', '4.1.1.1', '4.1.1.43', '4.1.1.74']),
#    ('subsystem', ['Butanoate metabolism']),
#    ('annotation',
#     [('bigg.reaction', 'ACALDCD'),
#      ('kegg.pathway', ['sce00010', 'sce01110', 'sce01130']),
#      ('metanetx.reaction', 'MNXR95211'),
#      ('pubmed', '12902239'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0096'),
#    ('name', 'acetohydroxy acid isomeroreductase'),
#    ('metabolites',
#     [('s_0016', 1),
#      ('s_0146', -1),
#      ('s_0799', -1),
#      ('s_1210', 1),
#      ('s_1214', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR355C'),
#    ('eccodes', '1.1.1.86'),
#    ('subsystem', ['Valine, leucine and isoleucine metabolism']),
#    ('annotation',
#     [('kegg.pathway',
#       ['sce00290',
#        'sce00770',
#        'sce01110',
#        'sce01130',
#        'sce01210',
#        'sce01230']),
#      ('pubmed', '8972574'),
#      ('sbo', 'SBO:0000176')]),
#    ('confidence_score', 3)],
#   [('id', 'r_0097'),
#    ('name', 'acetolactate synthase'),
#    ('metabolites',
#     [('s_0146', 1), ('s_0460', 1), ('s_0799', -1), ('s_1401', -2)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', '(YCL009C and YMR108W) or YMR108W'),
#    ('eccodes', '2.2.1.6'),
# ...
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation', [('pubmed', '16291748'), ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1231'),
#    ('name', 'NAD transport'),
#    ('metabolites',
#     [('s_0423', 1), ('s_0424', -1), ('s_1198', -1), ('s_1200', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YIL006W'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation', [('pubmed', '16291748'), ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1232'),
#    ('name', 'NAD transport'),
#    ('metabolites',
#     [('s_0615', 1), ('s_0616', -1), ('s_1198', -1), ('s_1200', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YIL006W'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation', [('pubmed', '16291748'), ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1235'),
#    ('name', 'nicotinate transport'),
#    ('metabolites', [('s_1219', 1), ('s_1220', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR260W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'NACt'),
#      ('metanetx.reaction', 'MNXR101808'),
#      ('pubmed', '10869563'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1236'),
#    ('name', 'octadecanoate (n-C18:0) transport'),
#    ('metabolites', [('s_1449', -1), ('s_1451', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YKL188C and YPL147W'),
#    ('subsystem', ['Transport [c, p]']),
#    ('annotation',
#     [('metanetx.reaction', 'MNXR99109'),
#      ('pubmed', '8993619'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1237'),
#    ('name', 'ornithine transport'),
#    ('metabolites',
#     [('s_0794', -1), ('s_0799', 1), ('s_1266', 1), ('s_1268', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YOR130C'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'ORNt3m'),
#      ('metanetx.reaction', 'MNXR102225'),
#      ('pubmed', '10428783'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1238'),
#    ('name', 'orntithine transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1266', 1), ('s_1267', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YKR039W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'ORNt2r'),
#      ('metanetx.reaction', 'MNXR102224'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1239'),
#    ('name', 'oxaloacetate transport'),
#    ('metabolites',
#     [('s_0794', -1), ('s_0799', 1), ('s_1271', -1), ('s_1273', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YKL120W'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'OAAt2m'),
#      ('metanetx.reaction', 'MNXR102102'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1241'),
#    ('name', 'pantothenate transport'),
#    ('metabolites',
#     [('s_0031', 1), ('s_0032', -1), ('s_0794', 1), ('s_0796', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YCR028C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'PNTOt2'),
#      ('metanetx.reaction', 'MNXR103053'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1242'),
#    ('name', 'pentaprenyl diphosphate transport'),
#    ('metabolites', [('s_1311', -1), ('s_1313', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'PENDPtm'),
#      ('metanetx.reaction', 'MNXR102483'),
#      ('pubmed', '11583838'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 0)],
#   [('id', 'r_1243'),
#    ('name', 'phenethyl acetate transport'),
#    ('metabolites', [('s_1316', -1), ('s_1317', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'PHEACt'),
#      ('metanetx.reaction', 'MNXR102622'),
#      ('pubmed', '10653746'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 0)],
#   [('id', 'r_1244'),
#    ('name', 'phosphate transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1322', 1), ('s_1324', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule',
#     'YBR296C or YCR037C or YJL198W or YML123C or YNR013C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'PIt2r'),
#      ('metanetx.reaction', 'MNXR102872'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1245'),
#    ('name', 'phosphate transport'),
#    ('metabolites',
#     [('s_0794', -1), ('s_0799', 1), ('s_1322', -1), ('s_1326', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YER053C or YJR077C'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'PIt2m'),
#      ('metanetx.reaction', 'MNXR102872'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1249'),
#    ('name', 'potassium transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1373', 1), ('s_1374', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR456W or YJL129C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'Kt2r'),
#      ('pubmed', '3043197'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1250'),
#    ('name', 'putrescine excretion'),
#    ('metabolites', [('s_1389', -1), ('s_1390', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 0),
#    ('gene_reaction_rule', 'YKL174C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'PTRCtex2'),
#      ('metanetx.reaction', 'MNXR103339'),
#      ('pubmed', '15668236'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1251'),
#    ('name', 'putrescine transport'),
#    ('metabolites',
#     [('s_0794', -1), ('s_0796', 1), ('s_1389', 1), ('s_1390', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLL028W or YOR273C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'PTRCt3i'),
#      ('metanetx.reaction', 'MNXR103341'),
#      ('pubmed', '9920864'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1252'),
#    ('name', 'putrescine transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0802', -1), ('s_1389', -1), ('s_1391', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLL028W or YOR273C'),
#    ('subsystem', ['Transport [c, v]']),
#    ('annotation',
#     [('metanetx.reaction', 'MNXR103341'),
#      ('pubmed', '11171066'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1253'),
#    ('name', 'pyridoxine symport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1396', 1), ('s_1397', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGL186C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation', [('pubmed', '12649274'), ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1254'),
#    ('name', 'pyruvate transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1399', 1), ('s_1400', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YKL217W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'PYRt2'),
#      ('metanetx.reaction', 'MNXR103385'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1255'),
#    ('name', 'S-adenosyl-L-methionine transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1416', 1), ('s_1418', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YPL274W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'AMETt2'),
#      ('metanetx.reaction', 'MNXR95810'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1256'),
#    ('name', 'S-adenosyl-L-methionine transport'),
#    ('metabolites', [('s_1416', -1), ('s_1419', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YNL003C'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'AMETtm'),
#      ('metanetx.reaction', 'MNXR95809'),
#      ('pubmed', '14609944'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1257'),
#    ('name', 'S-methylmethionine permease'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1424', 1), ('s_1425', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLL061W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'MMETt2'),
#      ('metanetx.reaction', 'MNXR101658'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1258'),
#    ('name', 'sodium proton antiporter'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1437', -1), ('s_1438', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YDR456W or YLR138W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation', [('bigg.reaction', 'NAt3_1'), ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1259'),
#    ('name', 'spermidine excretion'),
#    ('metabolites', [('s_1439', -1), ('s_1440', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 0),
#    ('gene_reaction_rule', 'YKL174C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'SPMDtex2'),
#      ('metanetx.reaction', 'MNXR104495'),
#      ('pubmed', '15668236'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1260'),
#    ('name', 'spermidine transport'),
#    ('metabolites',
#     [('s_0794', -1), ('s_0796', 1), ('s_1439', 1), ('s_1440', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule',
#     'YBR132C or YHL016C or YKR039W or YLL028W or YOR273C or YPL274W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'SPMDt3i'),
#      ('metanetx.reaction', 'MNXR104497'),
#      ('pubmed', ['17218313', '9920864']),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1261'),
#    ('name', 'spermidine transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0802', -1), ('s_1439', -1), ('s_1441', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLL028W or YOR273C'),
#    ('subsystem', ['Transport [c, v]']),
#    ('annotation',
#     [('metanetx.reaction', 'MNXR104497'),
#      ('pubmed', '11171066'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1262'),
#    ('name', 'spermine transport'),
#    ('metabolites',
#     [('s_0794', -1), ('s_0796', 1), ('s_1442', 1), ('s_1443', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR138C or YLL028W or YOR273C or YPR156C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'SPRMt2i'),
#      ('metanetx.reaction', 'MNXR104501'),
#      ('pubmed', '9920864'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1263'),
#    ('name', 'spermine transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0802', -1), ('s_1442', -1), ('s_1444', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR138C or YLL028W or YOR273C or YPR156C'),
#    ('subsystem', ['Transport [c, v]']),
#    ('annotation',
#     [('metanetx.reaction', 'MNXR104501'),
#      ('pubmed', '11171066'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1264'),
#    ('name', 'succinate transport'),
#    ('metabolites',
#     [('s_1322', 1), ('s_1326', -1), ('s_1458', -1), ('s_1460', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR348C'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'SUCCtm'),
#      ('metanetx.reaction', 'MNXR104626'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1265'),
#    ('name', 'succinate-fumarate transport'),
#    ('metabolites',
#     [('s_0725', 1), ('s_0727', -1), ('s_1458', -1), ('s_1460', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YJR095W'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'SUCFUMtm'),
#      ('metanetx.reaction', 'MNXR104633'),
#      ('pubmed', '9395087'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1266'),
#    ('name', 'sulfate uniport'),
#    ('metabolites', [('s_1467', 1), ('s_1468', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YBR294W or YLR092W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'SO4ti'),
#      ('metanetx.reaction', 'MNXR104469'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1267'),
#    ('name', 'sulfite transport'),
#    ('metabolites', [('s_1469', -1), ('s_1470', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YPL092W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'SO3ti'),
#      ('metanetx.reaction', 'MNXR104460'),
#      ('pubmed', '10870099'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1268'),
#    ('name', 'taurine transport'),
#    ('metabolites', [('s_1471', -1), ('s_1472', 1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'TAURt'),
#      ('metanetx.reaction', 'MNXR104733'),
#      ('pubmed', '8293962'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 0)],
#   [('id', 'r_1269'),
#    ('name', 'thiamine diphosphate transport'),
#    ('metabolites', [('s_1475', -1), ('s_1477', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YGR096W'),
#    ('subsystem', ['Transport [c, m]']),
#    ('annotation',
#     [('bigg.reaction', 'THMPPt2m'),
#      ('metanetx.reaction', 'MNXR104824'),
#      ('pubmed', '12411483'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1270'),
#    ('name', 'thiamine transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1489', 1), ('s_1490', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YLR237W or YOR071C or YOR192C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'THMt2'),
#      ('metanetx.reaction', 'MNXR138863'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1271'),
#    ('name', 'UDPgalactose transport'),
#    ('metabolites', [('s_1541', -1), ('s_1542', 1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YPL244C'),
#    ('subsystem', ['Transport [c, g]']),
#    ('annotation',
#     [('bigg.reaction', 'UDPGALt2g'),
#      ('metanetx.reaction', 'MNXR105061'),
#      ('pubmed', '11284009'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 3)],
#   [('id', 'r_1272'),
#    ('name', 'uracil transport'),
#    ('metabolites',
#     [('s_0794', 1), ('s_0796', -1), ('s_1550', 1), ('s_1551', -1)]),
#    ('lower_bound', 0),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YBR021W'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'URAt2'),
#      ('metanetx.reaction', 'MNXR105148'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   [('id', 'r_1273'),
#    ('name', 'urea transport'),
#    ('metabolites',
#     [('s_0794', 2), ('s_0796', -2), ('s_1552', 1), ('s_1553', -1)]),
#    ('lower_bound', -1000),
#    ('upper_bound', 1000),
#    ('gene_reaction_rule', 'YHL016C'),
#    ('subsystem', ['Transport [c, e]']),
#    ('annotation',
#     [('bigg.reaction', 'UREA2t2'),
#      ('metanetx.reaction', 'MNXR105154'),
#      ('sbo', 'SBO:0000655')]),
#    ('confidence_score', 2)],
#   ...])

# %% [raw]
# reactions[1]

# %% [raw]
# top_20

# %%
# get all names of reactions
names = []
for i in reactions[1][:20]:
    for j in i:
        if j[0] == 'name':
            names.append(j[1])

names
# Out:
# ['(R)-lactate:ferricytochrome-c 2-oxidoreductase',
#  '(R)-lactate:ferricytochrome-c 2-oxidoreductase',
#  '(R,R)-butanediol dehydrogenase',
#  '(S)-lactate:ferricytochrome-c 2-oxidoreductase',
#  '1,3-beta-glucan synthase',
#  '1,6-beta-glucan synthase',
#  '1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino)imidazole-4-carboxamide isomerase',
#  '1-pyrroline-5-carboxylate dehydrogenase',
#  '2,3-diketo-5-methylthio-1-phosphopentane degradation reaction',
#  "2,5-diamino-6-ribitylamino-4(3H)-pyrimidinone 5'-phosphate deaminase",
#  "2,5-diamino-6-ribosylamino-4(3H)-pyrimidinone 5'-phosphate reductase (NADPH)",
#  '2-aceto-2-hydroxybutanoate synthase',
#  '2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase',
#  '2-aminoadipate transaminase',
#  '2-dehydropantoate 2-reductase',
#  '2-deoxy-D-arabino-heptulosonate 7-phosphate synthetase',
#  '2-hexaprenyl-6-methoxy-1,4-benzoquinone methyltransferase',
#  '2-hexaprenyl-6-methoxyphenol monooxygenase',
#  '2-isopropylmalate hydratase',
#  '2-isopropylmalate synthase']

# %%
# get names of top 20 fluxes
top_names = []

for i in reactions[1]:
    #print(i[0][1])
    #for j in i:
     #   print(j[0])
    if i[0][1] in top_20:
        #print(i[0][1])
        for j in i:
            #print(j[0])
            if j[0] == 'name':

                top_names.append(j[1])

top_names
# Out:
# ['mitochondrial alcohol dehydrogenase',
#  'ATP synthase',
#  'ferrocytochrome-c:oxygen oxidoreductase',
#  'ubiquinol:ferricytochrome c reductase',
#  'isocitrate dehydrogenase (NAD+)',
#  'ADP/ATP transporter',
#  'phosphate transport',
#  'water diffusion',
#  'acetaldehyde transport',
#  'bicarbonate formation',
#  'carbon dioxide exchange',
#  'CO2 transport',
#  'CO2 transport',
#  'ethanol exchange',
#  'ethanol transport',
#  'ethanol transport, mitochondrial',
#  'water diffusion',
#  'water exchange',
#  '3-Oxopropanoate:NADP+ oxidoreductase (decarboxylating, CoA-acetylating)',
#  '3-oxopropanoate carboxy-lyase']

# %% [raw]
# # add reaction name to df
# fva_20['reaction name'] = ''
# fva_20['reaction name'] = [i for i in names]
# fva_20

# %%
# add reaction name to df
top_fva['reaction name'] = ''
top_fva['reaction name'] = [i for i in top_names]
top_fva
# Out:
#             minimum      maximum  \
# r_2100 -1000.000000  -338.135323
# r_1667  -426.076688  1000.000000
# r_0438   878.498633  1000.000000
# r_1277   338.135323  1000.000000
# r_1110   753.888060   902.271452
# r_2096 -1000.000000  -314.474198
# r_1245   518.022302   940.861777
# r_0226   493.788199   821.027644
# r_1763 -1000.000000   173.478743
# r_1632 -1000.000000  -192.954838
# r_0165   192.954838  1000.000000
# r_4575   217.183992   694.292978
# r_1761     0.000000   629.278906
# r_1762     0.000000   629.278906
# r_1696  -747.724567  -240.559231
# r_0439   439.249316   500.000000
# r_0658     0.000000   615.845258
# r_4574    98.193937   715.483771
# r_1672   116.905550   625.670219
# r_1697   116.905550   625.670219
#
#                                             reaction name
# r_2100                mitochondrial alcohol dehydrogenase
# r_1667                                       ATP synthase
# r_0438            ferrocytochrome-c:oxygen oxidoreductase
# r_1277              ubiquinol:ferricytochrome c reductase
# r_1110                    isocitrate dehydrogenase (NAD+)
# r_2096                                ADP/ATP transporter
# r_1245                                phosphate transport
# r_0226                                    water diffusion
# r_1763                             acetaldehyde transport
# r_1632                              bicarbonate formation
# r_0165                            carbon dioxide exchange
# r_4575                                      CO2 transport
# r_1761                                      CO2 transport
# r_1762                                   ethanol exchange
# r_1696                                  ethanol transport
# r_0439                   ethanol transport, mitochondrial
# r_0658                                    water diffusion
# r_4574                                     water exchange
# r_1672  3-Oxopropanoate:NADP+ oxidoreductase (decarbox...
# r_1697                      3-oxopropanoate carboxy-lyase
